# %% [markdown]
# # Group 08: Object detection for Images on Embedded Systems
# ### The network based on YOLOv2-tiny
# ###  Zhu Shien(G1801969B) & Mo Xiaoyun(G1702922E)

# %% [markdown]
#   This is the main notebook using the newest YOLO-like edition of Network to illustrate the development process of our work.<br>
#   The data preprocessing is in another notebook. <br>
#   There are three stages in this notebook: <br>
#   * training,
#   * inference,
#   * comparison between different networks we developed.
# ## Stage one: training
# Content:<br>
# *    import libries,
# *    functions for calculating IOU,
# *    function for getting classification accuracy,
# *    network configurations,
# *    training the network
# *    the result analysis

# %% [markdown]
# ### Import the libraries and our codes

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import utils
import os
import time
# These are our codes,
# readin_v5 is the latest version of reading in images and XML,
# mynet contains all the Neural Networks we created
import readin_v5
import mynet

# %% [markdown]
# ### A function for calculating the IOU of two bound boxes

# %%
# input the xmin, ymin, w, h of two boxes, then return the IOU
def cal_iou(infer,target):
    x=infer[0]
    y=infer[1]
    w=infer[2]
    h=infer[3]
    xt=target[0]
    yt=target[1]
    wt=target[2]
    ht=target[3]
    # case 0: when contained by the target
    if ((x+w)>=xt) and ((y+h)>=yt) and ((x+w)<=xt+wt) and ((y+h)<=yt+ht) and (x>=xt) and (y>=yt) and (x<=xt+wt) and (y<=yt+ht):
        same=w*h
        iou=same/(wt*ht)
    # case 1: when right upper part of infer is the same with target
    elif ((x+w)>=xt) and ((y+h)>=yt) and ((x+w)<=xt+wt) and ((y+h)<=yt+ht):
        same=(x+w-xt)*(y+h-yt)
        iou=same/(w*h+wt*ht-same)
    # case 2: right down part
    elif ((x+w)>=xt) and (y>=yt) and ((x+w)<=xt+wt) and (y<=yt+ht):
        same=(x+w-xt)*(yt+ht-y)
        iou=same/(w*h+wt*ht-same)
    # case 3: left upper part
    elif (x>=xt) and ((y+h)>=yt) and (x<=xt+wt) and ((y+h)<=yt+ht):
        same=(xt+wt-x)*(y+h-yt)
        iou=same/(w*h+wt*ht-same)
    # case 4: left down part
    elif (x>=xt) and (y>=yt) and (x<=xt+wt) and (y<=yt+ht):
        same=(xt+wt-x)*(yt+ht-y)
        iou=same/(w*h+wt*ht-same)
    # case 5: contain the target
    elif ((xt+wt)>=x) and ((yt+ht)>=y) and ((xt+wt)<=x+w) and ((yt+ht)<=y+h) and (xt>=x) and (yt>=y) and (xt<=x+w) and (yt<=y+h):
        same=wt*ht
        iou=same/(w*h)
    else :
        same=0.0
        iou=0.0
    del x,y,w,h,xt,yt,wt,ht,same
    return iou

# %% [markdown]
# ### Testing code for the cal_iou in different cases

# %%
target=[1.0,1.0,2.0,2.0]
# none
infer=[-1.0,-1.0,0.0,0.0]
print(cal_iou(infer,target))
# right upper part of infer is the same with target
infer=[-1.0,-1.0,3.0,3.0]
print(cal_iou(infer,target))
# right down
infer=[-1.0,2.0,3.0,3.0]
print(cal_iou(infer,target))
# left upper
infer=[2.0,2.0,3.0,3.0]
print(cal_iou(infer,target))
# left down
infer=[2.0,-1.0,3.0,3.0]
print(cal_iou(infer,target))
# contained by the target
infer=[2.0,2.0,1.0,1.0]
print(cal_iou(infer,target))
# contain the target
infer=[-1.0,-1.0,5.0,5.0]
print(cal_iou(infer,target))
# same
print(cal_iou(target,target))
# Out:
# 0.0
# 0.08333333333333333
# 0.08333333333333333
# 0.08333333333333333
# 0.08333333333333333
# 0.25
# 0.16
# 1.0

# %% [markdown]
# ### Calculate the mean IOU for a batch<br>
# Only pass the x,y,w,h into the cal_iou function<br>
# The outputs are a little bit large, so we devid them by 10 or 100, thus 30.5 -> 3.05, 640 -> 6.40<br>
# The ratio here is the same with the network design.<br>
# The output of x,y,w,h are all 10% of the real x,y,w,h, and both are devided by 10,<br>
# thus the numbers are 10 and 100.

# %%
def get_iou(out_prob,real_label,bs):
    iou_count=0.0
    for i in range(bs):
        iou_count=iou_count+cal_iou(out_prob[i,80:84]/10,real_label[i,1:5].float()/100)
    return(iou_count/bs)

# %% [markdown]
# ### A function to get the classification accuracy
# This function records the location of the highest value in a vector and campare with the real label, return the number of accurate labels in a batch.

# %%
def get_accu(out_prob,real_label,bs):
    count=0
    for i in range(bs):
        temp=0.0
        maxp=0
        for j in range(80):
            if temp<out_prob[i,j]:
                temp=out_prob[i,j]
                maxp=j
        if maxp==real_label[i,0]:
            count=count+1
    return(count)

# %% [markdown]
# ### Code for training
# Set the data path<br>
# This is the directionary organization:<br>
# codes.ipynb<br>
# training_record.txt<br>
# network_weight.pt<br>
# --train data<br>
# --train label<br>
# --small data<br>
# --small label<br>
# --test data<br>
# --test label

# %%
mydir=os.getcwd()
train_data_dir=mydir+"\\train_data"
train_label_dir=mydir+"\\train_label"
small_data_dir=mydir+"\\small_data"
small_label_dir=mydir+"\\small_label"

# %% [markdown]
# ### Configure the network and training process

# %%
# Define a new neural network,
# the original name is for identifying the training stragedy and network configurationsn    
net = mynet.yololike_v2()
origname="yololike_v2_6000"
record=open(origname+"_record.txt",mode='a')

# There are 6000 images for training and 900 images for small scale test
bs=20
lr=0.1   # the original learning rate is 0.1, and it will decrease when training
epoch_num=4   
train_data_num=100  # this number is for reading in images in parts, we cannot load in all images in RAM
train_total=6000  
small_num=900  # this is for small scale test within the training stage
iter_num=int(train_data_num/bs)  # this is for iteration when training 
criterion1 =nn.CrossEntropyLoss()  # there are two criteria for the loss function
criterion2 =nn.MSELoss()

# %% [markdown]
# ### Start training, and record the whole process

# %%
start_time = time.time()  
for epoch in range(epoch_num):
    # show and update learning rate
    print("lr=",lr)
    record.write("\nLearning rate: "+'{0:.6f}'.format(lr))
    for step in range(int(train_total/train_data_num)):
        # update the learning rate
        if (step>0) and (step%5==0) :
            del optimizer
            if lr>0.002 : # so that the lr is not too small
                lr=lr/2
                print("lr=",lr)
                record.write("\nLearning rate: "+'{0:.6f}'.format(lr))
        optimizer=torch.optim.SGD(net.parameters(),lr)
        
        # read in the data
        train_data = readin_v5.read_part_image(train_data_dir,step*train_data_num,train_data_num)
        train_label= readin_v5.read_part_xml(train_label_dir,step*train_data_num,train_data_num)
        print(train_data.size(),train_data.type())
        
        # train with batches
        accu_count=0
        step_loss=0.0
        iou_count=0.0
        for iter in range(iter_num):
            # delete the variables of last iteration, though not necessary
            if iter>0 :
                del indices
                del minibatch_data
                del minibatch_label
                del inputs
                del prob
                del loss
                del accu_batch
                
            # create a minibatch
            indices=iter*bs
            minibatch_data = train_data[indices:indices+bs]
            minibatch_label= train_label[indices:indices+bs]
    
            # feed the input to the net
            inputs=minibatch_data
            inputs.requires_grad_()
            prob=net(inputs)
    
            # update the weights
            loss=criterion1(prob[:,0:80], minibatch_label[:,0])+criterion2(prob[:,80:84]/10, minibatch_label[:,1:5].float()/100)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            step_loss=step_loss+loss.item()
            
            # get the accuracy and IOU
            accu_batch=get_accu(prob,minibatch_label,bs)
            accu_count=accu_count+accu_batch
            iou_batch=get_iou(prob,minibatch_label,bs)
            iou_item=iou_batch
            del iou_batch # sometimes somehow it should be deleted here
            iou_count=iou_count+iou_item
            
            # Show and record the results to get information about the training process
            print("batch no."+str(step*iter_num+iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                         " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))
            record.write("\nbatch no."+str(step*iter_num+iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                         " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))
        print("step loss: ",'{0:.2f}'.format(step_loss/iter_num)," accu=",'{0:.4f}'.format(accu_count/train_data_num),
              " iou="+'{0:.4f}'.format(iou_count/iter_num))
        record.write("\nstep loss: "+'{0:.4f}'.format(step_loss/iter_num)+" accu="+'{0:.4f}'.format(accu_count/train_data_num)+
                     " iou="+'{0:.4f}'.format(iou_count/iter_num)+" time: "+'{0:.2f}'.format(time.time()-start_time))   
    del train_data
    del train_label
    del indices
    del minibatch_data
    del minibatch_label
    del inputs
    del prob
    del loss
    
    # save the network in every epoch
    net_name=origname+"_epoch_"+str(epoch)+".pt"
    torch.save(net.state_dict(),net_name)
    
    # small scale test
    small_data = readin_v5.read_part_image(small_data_dir,0,small_num)
    small_label= readin_v5.read_part_xml(small_label_dir,0,small_num)
    small_loss=0.0
    accu_count=0
    iou_count=0.0
    for iter in range(int(small_num/bs)):
        if iter>0 :
            del indices
            del minibatch_data
            del minibatch_label
            del inputs
            del prob
            del loss
            del accu_batch
            del iou_item
                
        # create a minibatch
        indices=iter*bs
        minibatch_data = small_data[indices: indices+bs]
        minibatch_label= small_label[indices: indices+bs]
    
        # feed the input to the net
        inputs=minibatch_data
        prob=net(inputs)
        
        # get the accuracy and IOU
        accu_batch=get_accu(prob,minibatch_label,bs)
        accu_count=accu_count+accu_batch
        # the iou calculation is somehow strange, I have to delete the variable immediately,
        # otherwise the RAM will be fullly used, BUT I returned the iou as float, actually it is a tensor
        iou_batch=get_iou(prob,minibatch_label,bs)
        iou_item=iou_batch.item()
        del iou_batch 
        iou_count=iou_count+iou_item
        
        # get the loss
        loss=criterion1(prob[:,0:80], minibatch_label[:,0])+criterion2(prob[:,80:84]/10, minibatch_label[:,1:5].float()/100)
        small_loss=small_loss+loss.item()
        
        # show and record
        print("small_batch no."+str(iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                         " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))
        record.write("\nsmall_batch no."+str(step*iter_num+iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                     " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))
    del accu_batch
    del iou_item
    del indices
    del minibatch_data
    del minibatch_label
    del inputs
    del prob
    del loss   
    del small_data
    del small_label
    print("small loss:",'{0:.2f}'.format(small_loss/(small_num/bs))," accu=",'{0:.4f}'.format(accu_count/small_num),
          " iou=",'{0:.4f}'.format(iou_count/(small_num/bs)))
    record.write("small loss:"+'{0:.4f}'.format(small_loss/(small_num/bs))+" accuracy:"+'{0:.4f}'.format(accu_count/small_num)+
                 " iou="+'{0:.4f}'.format(iou_count/(small_num/bs)))
record.close()
# Out:
# lr= 0.1
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.0 loss: 7.4080 time: 6.56 accu=0 iou=0.0000
# batch no.1 loss: 6.8623 time: 11.97 accu=0 iou=0.0000
# batch no.2 loss: 6.4427 time: 17.55 accu=0 iou=0.0000
# batch no.3 loss: 7.8800 time: 23.03 accu=2 iou=0.0000
# batch no.4 loss: 6.2113 time: 28.52 accu=0 iou=0.0000
# step loss:  6.96  accu= 0.0200  iou=0.0000
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.5 loss: 8.7728 time: 34.85 accu=0 iou=0.0000
# batch no.6 loss: 5.2598 time: 40.31 accu=3 iou=0.0000
# batch no.7 loss: 5.9408 time: 45.74 accu=3 iou=0.0006
# batch no.8 loss: 6.7315 time: 51.34 accu=2 iou=0.0014
# batch no.9 loss: 7.1815 time: 56.62 accu=1 iou=0.0000
# step loss:  6.78  accu= 0.0900  iou=0.0004
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.10 loss: 7.8383 time: 64.23 accu=2 iou=0.0000
# batch no.11 loss: 5.1519 time: 69.83 accu=0 iou=0.0000
# batch no.12 loss: 4.8363 time: 75.56 accu=2 iou=0.0178
# batch no.13 loss: 4.2703 time: 81.15 accu=3 iou=0.0181
# batch no.14 loss: 4.2595 time: 86.62 accu=4 iou=0.0000
# step loss:  5.27  accu= 0.1100  iou=0.0072
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.15 loss: 4.7908 time: 94.14 accu=0 iou=0.0286
# batch no.16 loss: 5.5797 time: 101.67 accu=2 iou=0.0065
# batch no.17 loss: 5.1012 time: 107.12 accu=0 iou=0.0292
# batch no.18 loss: 4.5191 time: 112.56 accu=1 iou=0.0000
# batch no.19 loss: 4.6123 time: 117.92 accu=1 iou=0.0079
# step loss:  4.92  accu= 0.0400  iou=0.0144
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.20 loss: 4.3923 time: 125.49 accu=1 iou=0.0168
# batch no.21 loss: 4.5451 time: 131.07 accu=2 iou=0.0300
# batch no.22 loss: 4.1242 time: 137.01 accu=3 iou=0.0697
# batch no.23 loss: 3.9567 time: 142.71 accu=0 iou=0.0554
# batch no.24 loss: 3.8131 time: 148.18 accu=4 iou=0.1091
# step loss:  4.17  accu= 0.1000  iou=0.0562
# lr= 0.05
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.25 loss: 3.2299 time: 155.51 accu=7 iou=0.1132
# batch no.26 loss: 2.9410 time: 160.93 accu=8 iou=0.0783
# batch no.27 loss: 2.2273 time: 166.40 accu=13 iou=0.0442
# batch no.28 loss: 2.6727 time: 171.96 accu=9 iou=0.0319
# batch no.29 loss: 3.7642 time: 177.40 accu=8 iou=0.0386
# step loss:  2.97  accu= 0.4500  iou=0.0612
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.30 loss: 2.5038 time: 184.83 accu=11 iou=0.0789
# batch no.31 loss: 2.5417 time: 190.36 accu=10 iou=0.0857
# batch no.32 loss: 3.2772 time: 195.71 accu=6 iou=0.0858
# batch no.33 loss: 3.4912 time: 201.10 accu=7 iou=0.0459
# batch no.34 loss: 2.1069 time: 206.58 accu=9 iou=0.0468
# step loss:  2.78  accu= 0.4300  iou=0.0686
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.35 loss: 1.7536 time: 214.05 accu=12 iou=0.0119
# batch no.36 loss: 1.7760 time: 219.57 accu=14 iou=0.0663
# batch no.37 loss: 2.8880 time: 224.86 accu=8 iou=0.1098
# batch no.38 loss: 2.2520 time: 230.36 accu=10 iou=0.0731
# batch no.39 loss: 2.9924 time: 235.64 accu=7 iou=0.0384
# step loss:  2.33  accu= 0.5100  iou=0.0599
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.40 loss: 2.2322 time: 243.11 accu=12 iou=0.0687
# batch no.41 loss: 3.1673 time: 248.53 accu=6 iou=0.0517
# batch no.42 loss: 2.9318 time: 253.91 accu=9 iou=0.0356
# batch no.43 loss: 2.6100 time: 259.42 accu=6 iou=0.0445
# batch no.44 loss: 2.0245 time: 264.84 accu=10 iou=0.0598
# step loss:  2.59  accu= 0.4300  iou=0.0521
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.45 loss: 2.3721 time: 272.33 accu=11 iou=0.0536
# batch no.46 loss: 1.0675 time: 277.76 accu=18 iou=0.0572
# batch no.47 loss: 1.4617 time: 283.19 accu=12 iou=0.0660
# batch no.48 loss: 2.0886 time: 288.59 accu=11 iou=0.0979
# batch no.49 loss: 1.7525 time: 293.98 accu=11 iou=0.1560
# step loss:  1.75  accu= 0.6300  iou=0.0861
# lr= 0.025
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.50 loss: 1.1356 time: 301.51 accu=16 iou=0.0143
# batch no.51 loss: 1.5361 time: 306.98 accu=13 iou=0.0767
# batch no.52 loss: 1.4605 time: 312.32 accu=12 iou=0.1421
# batch no.53 loss: 1.5143 time: 317.68 accu=14 iou=0.1354
# batch no.54 loss: 1.3328 time: 323.03 accu=13 iou=0.0552
# step loss:  1.40  accu= 0.6800  iou=0.0847
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.55 loss: 1.9131 time: 329.31 accu=13 iou=0.0690
# batch no.56 loss: 1.0475 time: 334.99 accu=18 iou=0.1058
# batch no.57 loss: 1.4351 time: 340.42 accu=14 iou=0.1300
# batch no.58 loss: 1.7751 time: 345.84 accu=14 iou=0.0513
# batch no.59 loss: 1.5862 time: 351.38 accu=13 iou=0.0692
# step loss:  1.55  accu= 0.7200  iou=0.0851
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.60 loss: 1.6012 time: 357.66 accu=14 iou=0.0603
# batch no.61 loss: 1.5208 time: 363.07 accu=15 iou=0.0587
# batch no.62 loss: 1.5786 time: 368.45 accu=11 iou=0.0622
# batch no.63 loss: 1.0885 time: 373.87 accu=14 iou=0.0979
# batch no.64 loss: 1.5694 time: 379.21 accu=15 iou=0.0124
# step loss:  1.47  accu= 0.6900  iou=0.0583
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.65 loss: 0.9152 time: 385.51 accu=16 iou=0.0652
# batch no.66 loss: 0.7544 time: 390.88 accu=19 iou=0.0885
# batch no.67 loss: 1.1221 time: 396.24 accu=17 iou=0.0414
# batch no.68 loss: 1.1831 time: 401.61 accu=16 iou=0.1030
# batch no.69 loss: 1.3225 time: 407.05 accu=13 iou=0.0562
# step loss:  1.06  accu= 0.8100  iou=0.0709
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.70 loss: 1.0814 time: 414.79 accu=17 iou=0.0828
# batch no.71 loss: 1.3883 time: 420.19 accu=14 iou=0.0595
# batch no.72 loss: 1.1680 time: 425.50 accu=15 iou=0.0759
# batch no.73 loss: 1.3153 time: 430.82 accu=16 iou=0.0933
# batch no.74 loss: 1.3448 time: 436.28 accu=17 iou=0.0650
# step loss:  1.26  accu= 0.7900  iou=0.0753
# lr= 0.0125
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.75 loss: 1.1942 time: 444.11 accu=14 iou=0.0585
# batch no.76 loss: 1.1277 time: 450.86 accu=17 iou=0.1042
# batch no.77 loss: 1.1000 time: 456.31 accu=15 iou=0.0472
# batch no.78 loss: 0.9346 time: 461.77 accu=16 iou=0.1386
# batch no.79 loss: 0.9159 time: 467.50 accu=18 iou=0.1374
# step loss:  1.05  accu= 0.8000  iou=0.0972
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.80 loss: 1.4545 time: 475.52 accu=14 iou=0.0880
# batch no.81 loss: 0.7742 time: 480.94 accu=19 iou=0.0971
# batch no.82 loss: 0.4645 time: 486.36 accu=20 iou=0.1519
# batch no.83 loss: 1.2496 time: 491.70 accu=17 iou=0.0652
# batch no.84 loss: 1.0652 time: 497.14 accu=16 iou=0.1106
# step loss:  1.00  accu= 0.8600  iou=0.1026
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.85 loss: 1.0104 time: 504.47 accu=17 iou=0.1354
# batch no.86 loss: 1.1905 time: 509.89 accu=16 iou=0.0501
# batch no.87 loss: 1.1213 time: 515.40 accu=15 iou=0.0661
# batch no.88 loss: 0.9641 time: 521.01 accu=18 iou=0.0632
# batch no.89 loss: 0.7115 time: 526.43 accu=18 iou=0.1075
# step loss:  1.00  accu= 0.8400  iou=0.0845
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.90 loss: 1.0015 time: 534.01 accu=18 iou=0.1595
# batch no.91 loss: 0.8757 time: 539.43 accu=15 iou=0.1158
# batch no.92 loss: 1.0446 time: 544.71 accu=17 iou=0.0331
# batch no.93 loss: 1.1052 time: 550.09 accu=17 iou=0.1061
# batch no.94 loss: 1.1391 time: 555.53 accu=15 iou=0.0905
# step loss:  1.03  accu= 0.8200  iou=0.1010
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.95 loss: 1.1011 time: 562.98 accu=16 iou=0.0589
# batch no.96 loss: 1.3206 time: 568.32 accu=15 iou=0.0636
# batch no.97 loss: 0.5994 time: 573.79 accu=20 iou=0.1173
# batch no.98 loss: 0.7885 time: 579.21 accu=17 iou=0.1328
# batch no.99 loss: 1.4609 time: 584.62 accu=15 iou=0.0968
# step loss:  1.05  accu= 0.8300  iou=0.0939
# lr= 0.00625
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.100 loss: 0.6739 time: 592.16 accu=19 iou=0.1208
# batch no.101 loss: 0.8790 time: 597.48 accu=17 iou=0.0948
# batch no.102 loss: 0.8603 time: 602.87 accu=17 iou=0.0737
# batch no.103 loss: 0.5302 time: 608.26 accu=19 iou=0.1296
# batch no.104 loss: 0.5289 time: 613.65 accu=19 iou=0.1119
# step loss:  0.69  accu= 0.9100  iou=0.1062
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.105 loss: 1.3355 time: 620.96 accu=14 iou=0.0429
# batch no.106 loss: 0.9406 time: 626.33 accu=18 iou=0.1238
# batch no.107 loss: 0.7155 time: 631.63 accu=18 iou=0.0907
# batch no.108 loss: 0.7484 time: 636.93 accu=18 iou=0.1031
# batch no.109 loss: 0.8070 time: 642.36 accu=18 iou=0.0158
# step loss:  0.91  accu= 0.8600  iou=0.0753
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.110 loss: 0.7078 time: 649.89 accu=17 iou=0.0406
# batch no.111 loss: 0.7133 time: 655.25 accu=19 iou=0.1448
# batch no.112 loss: 0.4962 time: 660.60 accu=19 iou=0.1373
# batch no.113 loss: 0.7110 time: 665.99 accu=19 iou=0.0872
# batch no.114 loss: 0.8274 time: 671.42 accu=17 iou=0.0480
# step loss:  0.69  accu= 0.9100  iou=0.0916
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.115 loss: 0.8633 time: 678.97 accu=19 iou=0.1332
# batch no.116 loss: 1.1482 time: 684.38 accu=13 iou=0.0632
# batch no.117 loss: 0.9205 time: 689.86 accu=16 iou=0.0790
# batch no.118 loss: 0.5864 time: 695.27 accu=18 iou=0.1232
# batch no.119 loss: 0.8896 time: 700.73 accu=16 iou=0.0970
# step loss:  0.88  accu= 0.8200  iou=0.0991
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.120 loss: 0.8771 time: 718.67 accu=17 iou=0.0969
# batch no.121 loss: 1.1218 time: 724.06 accu=17 iou=0.0546
# batch no.122 loss: 0.7830 time: 729.44 accu=17 iou=0.0992
# batch no.123 loss: 0.9431 time: 734.84 accu=18 iou=0.0652
# batch no.124 loss: 0.9751 time: 740.26 accu=17 iou=0.0511
# step loss:  0.94  accu= 0.8600  iou=0.0734
# lr= 0.003125
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.125 loss: 0.5227 time: 753.89 accu=19 iou=0.0713
# batch no.126 loss: 0.4180 time: 759.25 accu=20 iou=0.1034
# batch no.127 loss: 0.8734 time: 764.61 accu=18 iou=0.0423
# batch no.128 loss: 0.9808 time: 770.67 accu=17 iou=0.0250
# batch no.129 loss: 0.8508 time: 775.99 accu=17 iou=0.1230
# step loss:  0.73  accu= 0.9100  iou=0.0730
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.130 loss: 1.3442 time: 783.35 accu=17 iou=0.1197
# batch no.131 loss: 0.7592 time: 788.93 accu=18 iou=0.0577
# batch no.132 loss: 0.4786 time: 794.38 accu=20 iou=0.0928
# batch no.133 loss: 0.6760 time: 799.88 accu=18 iou=0.1132
# batch no.134 loss: 0.6072 time: 805.21 accu=18 iou=0.0498
# step loss:  0.77  accu= 0.9100  iou=0.0867
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.135 loss: 0.4802 time: 812.63 accu=20 iou=0.1346
# batch no.136 loss: 0.5692 time: 818.07 accu=20 iou=0.0816
# batch no.137 loss: 0.8168 time: 823.48 accu=19 iou=0.1211
# batch no.138 loss: 1.1110 time: 828.91 accu=16 iou=0.0591
# batch no.139 loss: 0.5832 time: 834.37 accu=19 iou=0.1258
# step loss:  0.71  accu= 0.9400  iou=0.1045
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.140 loss: 0.8182 time: 841.58 accu=16 iou=0.0910
# batch no.141 loss: 0.7458 time: 846.93 accu=18 iou=0.0560
# batch no.142 loss: 0.9795 time: 852.32 accu=16 iou=0.0507
# batch no.143 loss: 0.5801 time: 857.74 accu=19 iou=0.1595
# batch no.144 loss: 0.7673 time: 863.16 accu=18 iou=0.1410
# step loss:  0.78  accu= 0.8700  iou=0.0996
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.145 loss: 0.9455 time: 870.38 accu=18 iou=0.0322
# batch no.146 loss: 0.6649 time: 875.75 accu=19 iou=0.1209
# batch no.147 loss: 0.8575 time: 881.10 accu=17 iou=0.0846
# batch no.148 loss: 0.6523 time: 886.53 accu=19 iou=0.0310
# batch no.149 loss: 0.5061 time: 892.08 accu=18 iou=0.1013
# step loss:  0.73  accu= 0.9100  iou=0.0740
# lr= 0.0015625
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.150 loss: 0.7154 time: 899.39 accu=17 iou=0.1109
# batch no.151 loss: 0.7461 time: 904.80 accu=18 iou=0.1102
# batch no.152 loss: 0.7607 time: 910.33 accu=18 iou=0.1048
# batch no.153 loss: 0.8282 time: 915.77 accu=18 iou=0.0560
# batch no.154 loss: 0.5860 time: 921.08 accu=19 iou=0.1422
# step loss:  0.73  accu= 0.9000  iou=0.1048
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.155 loss: 0.8966 time: 928.44 accu=17 iou=0.0977
# batch no.156 loss: 0.9130 time: 933.92 accu=18 iou=0.1255
# batch no.157 loss: 0.4171 time: 939.30 accu=20 iou=0.0938
# batch no.158 loss: 0.5976 time: 944.72 accu=20 iou=0.1196
# batch no.159 loss: 0.6145 time: 950.15 accu=20 iou=0.1155
# step loss:  0.69  accu= 0.9500  iou=0.1104
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.160 loss: 0.5539 time: 957.78 accu=19 iou=0.1242
# batch no.161 loss: 0.5790 time: 963.20 accu=18 iou=0.1486
# batch no.162 loss: 0.7737 time: 968.62 accu=17 iou=0.1528
# batch no.163 loss: 0.5796 time: 974.01 accu=18 iou=0.1054
# batch no.164 loss: 0.8072 time: 979.45 accu=17 iou=0.0799
# step loss:  0.66  accu= 0.8900  iou=0.1222
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.165 loss: 0.6824 time: 986.90 accu=17 iou=0.1659
# batch no.166 loss: 0.5344 time: 992.32 accu=19 iou=0.0950
# batch no.167 loss: 1.0189 time: 997.65 accu=15 iou=0.0732
# batch no.168 loss: 0.5994 time: 1003.09 accu=19 iou=0.0553
# batch no.169 loss: 0.6622 time: 1008.45 accu=19 iou=0.0914
# step loss:  0.70  accu= 0.8900  iou=0.0962
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.170 loss: 0.6659 time: 1015.90 accu=19 iou=0.1498
# batch no.171 loss: 0.8638 time: 1021.37 accu=17 iou=0.0832
# batch no.172 loss: 1.0491 time: 1026.81 accu=17 iou=0.0545
# batch no.173 loss: 0.7551 time: 1032.27 accu=19 iou=0.1751
# batch no.174 loss: 0.5634 time: 1037.70 accu=20 iou=0.1001
# step loss:  0.78  accu= 0.9200  iou=0.1125
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.175 loss: 0.7441 time: 1045.12 accu=19 iou=0.0659
# batch no.176 loss: 0.4683 time: 1050.57 accu=20 iou=0.0375
# batch no.177 loss: 0.6363 time: 1055.93 accu=20 iou=0.0717
# batch no.178 loss: 0.7166 time: 1061.29 accu=19 iou=0.1552
# batch no.179 loss: 0.7542 time: 1066.66 accu=18 iou=0.1203
# step loss:  0.66  accu= 0.9600  iou=0.0901
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.180 loss: 0.9363 time: 1074.18 accu=16 iou=0.1215
# batch no.181 loss: 0.5354 time: 1079.63 accu=19 iou=0.0322
# batch no.182 loss: 0.5253 time: 1085.05 accu=19 iou=0.0143
# batch no.183 loss: 0.7380 time: 1090.49 accu=18 iou=0.0894
# batch no.184 loss: 1.0845 time: 1095.88 accu=15 iou=0.0582
# step loss:  0.76  accu= 0.8700  iou=0.0631
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.185 loss: 0.5706 time: 1103.19 accu=19 iou=0.0587
# batch no.186 loss: 0.7691 time: 1108.63 accu=18 iou=0.0349
# batch no.187 loss: 0.7661 time: 1113.97 accu=16 iou=0.1393
# batch no.188 loss: 0.5270 time: 1119.39 accu=18 iou=0.0839
# batch no.189 loss: 1.2481 time: 1124.80 accu=16 iou=0.0582
# step loss:  0.78  accu= 0.8700  iou=0.0750
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.190 loss: 0.7233 time: 1132.27 accu=17 iou=0.0079
# batch no.191 loss: 0.6202 time: 1137.74 accu=19 iou=0.0595
# batch no.192 loss: 0.5344 time: 1143.13 accu=19 iou=0.1420
# batch no.193 loss: 0.8305 time: 1148.52 accu=18 iou=0.0758
# batch no.194 loss: 0.4822 time: 1153.95 accu=19 iou=0.0545
# step loss:  0.64  accu= 0.9200  iou=0.0680
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.195 loss: 0.9453 time: 1161.34 accu=16 iou=0.0341
# batch no.196 loss: 0.4883 time: 1166.81 accu=20 iou=0.1905
# batch no.197 loss: 0.5450 time: 1172.20 accu=19 iou=0.0113
# batch no.198 loss: 0.9452 time: 1177.69 accu=16 iou=0.0878
# batch no.199 loss: 0.7892 time: 1183.20 accu=19 iou=0.0842
# step loss:  0.74  accu= 0.9000  iou=0.0816
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.200 loss: 0.7908 time: 1190.83 accu=17 iou=0.0780
# batch no.201 loss: 0.8594 time: 1196.18 accu=18 iou=0.0788
# batch no.202 loss: 0.8841 time: 1201.61 accu=17 iou=0.0773
# batch no.203 loss: 0.7253 time: 1207.00 accu=19 iou=0.0991
# batch no.204 loss: 0.5118 time: 1212.35 accu=18 iou=0.0756
# step loss:  0.75  accu= 0.8900  iou=0.0818
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.205 loss: 0.5044 time: 1219.85 accu=20 iou=0.1061
# batch no.206 loss: 0.6329 time: 1225.32 accu=17 iou=0.0958
# batch no.207 loss: 0.8381 time: 1230.76 accu=17 iou=0.1119
# batch no.208 loss: 0.6377 time: 1236.21 accu=19 iou=0.0233
# batch no.209 loss: 0.8656 time: 1241.62 accu=19 iou=0.0491
# step loss:  0.70  accu= 0.9200  iou=0.0772
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.210 loss: 0.5975 time: 1249.18 accu=19 iou=0.0272
# batch no.211 loss: 0.4636 time: 1254.62 accu=18 iou=0.0908
# batch no.212 loss: 0.7281 time: 1260.04 accu=18 iou=0.0076
# batch no.213 loss: 0.5428 time: 1265.43 accu=19 iou=0.0751
# batch no.214 loss: 0.7736 time: 1270.85 accu=18 iou=0.0519
# step loss:  0.62  accu= 0.9200  iou=0.0505
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.215 loss: 0.7844 time: 1278.52 accu=18 iou=0.0903
# batch no.216 loss: 0.9648 time: 1284.24 accu=17 iou=0.1029
# batch no.217 loss: 0.6503 time: 1289.82 accu=19 iou=0.0431
# batch no.218 loss: 0.6691 time: 1295.29 accu=18 iou=0.0453
# batch no.219 loss: 0.5536 time: 1300.68 accu=18 iou=0.0414
# step loss:  0.72  accu= 0.9000  iou=0.0646
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.220 loss: 0.6815 time: 1308.18 accu=20 iou=0.0493
# batch no.221 loss: 0.6709 time: 1313.71 accu=19 iou=0.0770
# batch no.222 loss: 0.7124 time: 1319.11 accu=17 iou=0.0759
# batch no.223 loss: 0.6789 time: 1324.43 accu=19 iou=0.0925
# batch no.224 loss: 0.7842 time: 1329.92 accu=17 iou=0.1249
# step loss:  0.71  accu= 0.9200  iou=0.0839
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.225 loss: 0.3884 time: 1337.64 accu=18 iou=0.0502
# batch no.226 loss: 0.8054 time: 1342.95 accu=17 iou=0.1080
# batch no.227 loss: 0.5641 time: 1348.22 accu=20 iou=0.0895
# batch no.228 loss: 0.7129 time: 1353.58 accu=19 iou=0.0563
# batch no.229 loss: 0.7183 time: 1358.92 accu=18 iou=0.0766
# step loss:  0.64  accu= 0.9200  iou=0.0762
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.230 loss: 0.4030 time: 1366.38 accu=20 iou=0.1334
# batch no.231 loss: 0.6804 time: 1371.97 accu=18 iou=0.1114
# batch no.232 loss: 0.4258 time: 1377.33 accu=20 iou=0.0527
# batch no.233 loss: 0.8069 time: 1382.75 accu=17 iou=0.0535
# batch no.234 loss: 0.4373 time: 1388.09 accu=19 iou=0.0774
# step loss:  0.55  accu= 0.9400  iou=0.0857
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.235 loss: 0.6406 time: 1395.64 accu=18 iou=0.1132
# batch no.236 loss: 0.5315 time: 1400.92 accu=19 iou=0.0770
# batch no.237 loss: 0.4641 time: 1406.29 accu=19 iou=0.1257
# batch no.238 loss: 0.6290 time: 1411.67 accu=19 iou=0.0915
# batch no.239 loss: 0.5248 time: 1416.92 accu=20 iou=0.0733
# step loss:  0.56  accu= 0.9500  iou=0.0962
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.240 loss: 0.5436 time: 1424.45 accu=19 iou=0.1064
# batch no.241 loss: 0.7002 time: 1429.90 accu=18 iou=0.0892
# batch no.242 loss: 0.8538 time: 1435.25 accu=19 iou=0.1214
# batch no.243 loss: 0.5689 time: 1440.53 accu=17 iou=0.0871
# batch no.244 loss: 0.4023 time: 1445.95 accu=19 iou=0.0779
# step loss:  0.61  accu= 0.9200  iou=0.0964
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.245 loss: 0.7408 time: 1453.42 accu=16 iou=0.0449
# batch no.246 loss: 0.6011 time: 1458.71 accu=19 iou=0.1086
# batch no.247 loss: 1.2035 time: 1464.07 accu=16 iou=0.2122
# batch no.248 loss: 0.8652 time: 1469.46 accu=17 iou=0.1222
# batch no.249 loss: 0.7334 time: 1474.84 accu=19 iou=0.0913
# step loss:  0.83  accu= 0.8700  iou=0.1158
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.250 loss: 0.4978 time: 1482.20 accu=19 iou=0.0831
# batch no.251 loss: 1.1681 time: 1487.60 accu=16 iou=0.0533
# batch no.252 loss: 0.4734 time: 1493.16 accu=19 iou=0.1037
# batch no.253 loss: 0.4105 time: 1498.55 accu=20 iou=0.1967
# batch no.254 loss: 0.5691 time: 1503.96 accu=18 iou=0.0876
# step loss:  0.62  accu= 0.9200  iou=0.1049
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.255 loss: 0.7147 time: 1511.33 accu=17 iou=0.0907
# batch no.256 loss: 0.8543 time: 1516.77 accu=18 iou=0.1165
# batch no.257 loss: 0.7801 time: 1522.19 accu=17 iou=0.0688
# batch no.258 loss: 0.7807 time: 1527.54 accu=18 iou=0.0912
# batch no.259 loss: 0.9488 time: 1532.94 accu=17 iou=0.1084
# step loss:  0.82  accu= 0.8700  iou=0.0951
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.260 loss: 0.7959 time: 1540.63 accu=18 iou=0.0917
# batch no.261 loss: 0.8446 time: 1546.02 accu=18 iou=0.0740
# batch no.262 loss: 0.8675 time: 1551.52 accu=18 iou=0.0252
# batch no.263 loss: 0.4930 time: 1556.85 accu=19 iou=0.1681
# batch no.264 loss: 0.6336 time: 1562.19 accu=17 iou=0.0767
# step loss:  0.73  accu= 0.9000  iou=0.0872
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.265 loss: 0.5241 time: 1569.70 accu=20 iou=0.0618
# batch no.266 loss: 0.7798 time: 1575.22 accu=18 iou=0.1073
# batch no.267 loss: 0.9898 time: 1580.56 accu=17 iou=0.0307
# batch no.268 loss: 0.5317 time: 1585.98 accu=19 iou=0.1102
# batch no.269 loss: 0.5897 time: 1591.39 accu=19 iou=0.1807
# step loss:  0.68  accu= 0.9300  iou=0.0981
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.270 loss: 0.3604 time: 1598.66 accu=20 iou=0.0732
# batch no.271 loss: 0.8158 time: 1604.06 accu=18 iou=0.0931
# batch no.272 loss: 0.9370 time: 1609.56 accu=17 iou=0.1049
# batch no.273 loss: 0.3950 time: 1614.94 accu=20 iou=0.0673
# batch no.274 loss: 0.7005 time: 1620.29 accu=19 iou=0.1222
# step loss:  0.64  accu= 0.9400  iou=0.0921
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.275 loss: 0.4462 time: 1627.61 accu=20 iou=0.1075
# batch no.276 loss: 0.7470 time: 1633.08 accu=18 iou=0.0787
# batch no.277 loss: 0.7003 time: 1638.56 accu=18 iou=0.0864
# batch no.278 loss: 0.3547 time: 1644.01 accu=20 iou=0.0869
# batch no.279 loss: 0.6145 time: 1649.45 accu=19 iou=0.0754
# step loss:  0.57  accu= 0.9500  iou=0.0870
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.280 loss: 0.4049 time: 1656.76 accu=18 iou=0.0838
# batch no.281 loss: 0.5348 time: 1662.15 accu=20 iou=0.1966
# batch no.282 loss: 0.4487 time: 1667.53 accu=18 iou=0.0777
# batch no.283 loss: 0.5198 time: 1673.15 accu=18 iou=0.1372
# batch no.284 loss: 1.0829 time: 1678.56 accu=15 iou=0.1291
# step loss:  0.60  accu= 0.8900  iou=0.1249
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.285 loss: 0.5201 time: 1685.96 accu=19 iou=0.0547
# batch no.286 loss: 0.4445 time: 1691.40 accu=20 iou=0.0270
# batch no.287 loss: 0.8496 time: 1696.77 accu=17 iou=0.0668
# batch no.288 loss: 0.5876 time: 1702.21 accu=19 iou=0.1162
# batch no.289 loss: 0.7031 time: 1707.55 accu=17 iou=0.1154
# step loss:  0.62  accu= 0.9200  iou=0.0760
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.290 loss: 0.9153 time: 1714.87 accu=16 iou=0.0942
# batch no.291 loss: 0.7761 time: 1720.27 accu=18 iou=0.1022
# batch no.292 loss: 0.3368 time: 1725.63 accu=20 iou=0.1114
# batch no.293 loss: 1.2640 time: 1731.18 accu=16 iou=0.0416
# batch no.294 loss: 0.3008 time: 1736.60 accu=20 iou=0.1218
# step loss:  0.72  accu= 0.9000  iou=0.0943
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.295 loss: 0.6803 time: 1744.02 accu=20 iou=0.0822
# batch no.296 loss: 0.6684 time: 1749.49 accu=18 iou=0.0848
# batch no.297 loss: 0.4585 time: 1754.89 accu=20 iou=0.0411
# batch no.298 loss: 0.6084 time: 1760.35 accu=18 iou=0.0884
# batch no.299 loss: 0.3840 time: 1765.83 accu=20 iou=0.0146
# step loss:  0.56  accu= 0.9600  iou=0.0622
# small_batch no.0 loss: 0.7749 time: 1774.19 accu=19 iou=0.0825
# small_batch no.1 loss: 0.4766 time: 1776.53 accu=20 iou=0.1374
# small_batch no.2 loss: 0.4470 time: 1778.91 accu=19 iou=0.1198
# small_batch no.3 loss: 0.9859 time: 1781.28 accu=17 iou=0.0591
# small_batch no.4 loss: 0.9045 time: 1783.66 accu=17 iou=0.0878
# small_batch no.5 loss: 0.6038 time: 1786.06 accu=19 iou=0.1697
# small_batch no.6 loss: 0.5553 time: 1788.60 accu=19 iou=0.1477
# small_batch no.7 loss: 0.8115 time: 1790.97 accu=17 iou=0.0924
# small_batch no.8 loss: 0.6315 time: 1793.31 accu=19 iou=0.1028
# small_batch no.9 loss: 0.7287 time: 1795.69 accu=19 iou=0.0523
# small_batch no.10 loss: 0.4203 time: 1798.06 accu=18 iou=0.1311
# small_batch no.11 loss: 0.6019 time: 1800.52 accu=18 iou=0.0497
# small_batch no.12 loss: 0.4991 time: 1802.88 accu=19 iou=0.0701
# small_batch no.13 loss: 0.5511 time: 1805.33 accu=19 iou=0.0351
# small_batch no.14 loss: 0.7495 time: 1807.70 accu=17 iou=0.1345
# small_batch no.15 loss: 0.4116 time: 1810.06 accu=19 iou=0.1764
# small_batch no.16 loss: 0.7725 time: 1812.48 accu=16 iou=0.0278
# small_batch no.17 loss: 0.7451 time: 1814.86 accu=18 iou=0.1137
# small_batch no.18 loss: 0.4232 time: 1817.23 accu=20 iou=0.0491
# small_batch no.19 loss: 0.5883 time: 1819.59 accu=19 iou=0.0975
# small_batch no.20 loss: 0.7156 time: 1821.97 accu=17 iou=0.0305
# small_batch no.21 loss: 0.4675 time: 1824.39 accu=19 iou=0.1369
# small_batch no.22 loss: 0.4200 time: 1826.75 accu=20 iou=0.1085
# small_batch no.23 loss: 0.4764 time: 1829.12 accu=19 iou=0.0389
# small_batch no.24 loss: 0.4561 time: 1831.55 accu=19 iou=0.1149
# small_batch no.25 loss: 1.2071 time: 1833.95 accu=15 iou=0.0619
# small_batch no.26 loss: 0.9399 time: 1836.34 accu=17 iou=0.1125
# small_batch no.27 loss: 0.6137 time: 1838.78 accu=18 iou=0.1203
# small_batch no.28 loss: 0.7601 time: 1841.15 accu=17 iou=0.1426
# small_batch no.29 loss: 0.5699 time: 1843.54 accu=19 iou=0.0679
# small_batch no.30 loss: 0.5668 time: 1845.86 accu=20 iou=0.0844
# small_batch no.31 loss: 0.7631 time: 1848.29 accu=18 iou=0.0942
# small_batch no.32 loss: 0.7893 time: 1850.68 accu=18 iou=0.1244
# small_batch no.33 loss: 0.5273 time: 1853.06 accu=18 iou=0.1482
# small_batch no.34 loss: 0.6418 time: 1855.43 accu=18 iou=0.0807
# small_batch no.35 loss: 0.4885 time: 1857.89 accu=19 iou=0.1023
# small_batch no.36 loss: 0.6912 time: 1860.31 accu=17 iou=0.0234
# small_batch no.37 loss: 0.6238 time: 1862.81 accu=19 iou=0.2515
# small_batch no.38 loss: 0.6628 time: 1865.20 accu=19 iou=0.0399
# small_batch no.39 loss: 0.5707 time: 1867.61 accu=18 iou=0.0732
# small_batch no.40 loss: 0.5789 time: 1869.96 accu=19 iou=0.0801
# small_batch no.41 loss: 0.5634 time: 1872.37 accu=20 iou=0.1623
# small_batch no.42 loss: 0.5662 time: 1874.78 accu=19 iou=0.1324
# small_batch no.43 loss: 0.5722 time: 1877.12 accu=20 iou=0.1121
# small_batch no.44 loss: 1.0030 time: 1879.51 accu=16 iou=0.0767
# small loss: 0.64  accu= 0.9178  iou= 0.0991
# lr= 0.0015625
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.0 loss: 0.7186 time: 1886.31 accu=18 iou=0.0711
# batch no.1 loss: 0.4036 time: 1891.76 accu=20 iou=0.1056
# batch no.2 loss: 0.5800 time: 1897.46 accu=19 iou=0.1269
# batch no.3 loss: 0.7382 time: 1902.98 accu=18 iou=0.0896
# batch no.4 loss: 0.4091 time: 1909.31 accu=19 iou=0.1396
# step loss:  0.57  accu= 0.9400  iou=0.1066
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.5 loss: 0.3981 time: 1915.57 accu=20 iou=0.0983
# batch no.6 loss: 0.4499 time: 1920.95 accu=20 iou=0.0598
# batch no.7 loss: 0.5254 time: 1926.48 accu=20 iou=0.0268
# batch no.8 loss: 0.4579 time: 1931.87 accu=18 iou=0.1264
# batch no.9 loss: 0.5911 time: 1937.43 accu=18 iou=0.0623
# step loss:  0.48  accu= 0.9600  iou=0.0747
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.10 loss: 0.5809 time: 1943.62 accu=19 iou=0.0584
# batch no.11 loss: 0.6591 time: 1948.93 accu=17 iou=0.0399
# batch no.12 loss: 0.3851 time: 1954.30 accu=18 iou=0.0456
# batch no.13 loss: 0.4630 time: 1959.68 accu=19 iou=0.0195
# batch no.14 loss: 0.5540 time: 1965.02 accu=20 iou=0.0500
# step loss:  0.53  accu= 0.9300  iou=0.0427
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.15 loss: 0.3645 time: 1971.36 accu=20 iou=0.0285
# batch no.16 loss: 0.6162 time: 1976.94 accu=18 iou=0.0722
# batch no.17 loss: 0.5109 time: 1982.33 accu=19 iou=0.0808
# batch no.18 loss: 0.4985 time: 1987.74 accu=19 iou=0.0853
# batch no.19 loss: 0.3632 time: 1993.19 accu=20 iou=0.1498
# step loss:  0.47  accu= 0.9600  iou=0.0833
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.20 loss: 0.3116 time: 1999.35 accu=19 iou=0.0302
# batch no.21 loss: 0.6439 time: 2004.61 accu=18 iou=0.0765
# batch no.22 loss: 0.5454 time: 2010.02 accu=17 iou=0.1515
# batch no.23 loss: 0.3498 time: 2015.49 accu=20 iou=0.0619
# batch no.24 loss: 0.5463 time: 2020.86 accu=20 iou=0.0960
# step loss:  0.48  accu= 0.9400  iou=0.0832
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.25 loss: 0.2367 time: 2027.11 accu=20 iou=0.0778
# batch no.26 loss: 0.3923 time: 2032.58 accu=20 iou=0.0420
# batch no.27 loss: 0.5406 time: 2038.05 accu=19 iou=0.0973
# batch no.28 loss: 0.4606 time: 2043.42 accu=19 iou=0.0338
# batch no.29 loss: 0.5937 time: 2048.91 accu=18 iou=0.0877
# step loss:  0.44  accu= 0.9600  iou=0.0677
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.30 loss: 0.4178 time: 2055.25 accu=19 iou=0.1099
# batch no.31 loss: 0.7450 time: 2060.62 accu=18 iou=0.1795
# batch no.32 loss: 0.4631 time: 2066.12 accu=19 iou=0.1543
# batch no.33 loss: 0.6776 time: 2071.43 accu=18 iou=0.0439
# batch no.34 loss: 0.3696 time: 2076.83 accu=19 iou=0.0713
# step loss:  0.53  accu= 0.9300  iou=0.1118
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.35 loss: 0.2829 time: 2083.01 accu=20 iou=0.0992
# batch no.36 loss: 0.4047 time: 2088.50 accu=20 iou=0.0894
# batch no.37 loss: 0.5756 time: 2093.89 accu=18 iou=0.1623
# batch no.38 loss: 0.6312 time: 2099.35 accu=19 iou=0.1475
# batch no.39 loss: 0.9260 time: 2104.76 accu=17 iou=0.0664
# step loss:  0.56  accu= 0.9400  iou=0.1129
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.40 loss: 0.6431 time: 2111.10 accu=19 iou=0.1002
# batch no.41 loss: 0.7170 time: 2116.45 accu=17 iou=0.0155
# batch no.42 loss: 0.6304 time: 2121.88 accu=18 iou=0.0560
# batch no.43 loss: 0.7690 time: 2127.38 accu=18 iou=0.1265
# batch no.44 loss: 0.4829 time: 2132.79 accu=18 iou=0.0923
# step loss:  0.65  accu= 0.9000  iou=0.0781
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.45 loss: 0.4804 time: 2139.10 accu=20 iou=0.1043
# batch no.46 loss: 0.2959 time: 2144.52 accu=20 iou=0.0668
# batch no.47 loss: 0.4327 time: 2150.01 accu=20 iou=0.0809
# batch no.48 loss: 0.5828 time: 2155.44 accu=18 iou=0.0304
# batch no.49 loss: 0.4173 time: 2160.85 accu=20 iou=0.1565
# step loss:  0.44  accu= 0.9800  iou=0.0878
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.50 loss: 0.4789 time: 2167.12 accu=19 iou=0.0412
# batch no.51 loss: 0.3777 time: 2172.44 accu=20 iou=0.1249
# batch no.52 loss: 0.3913 time: 2177.79 accu=19 iou=0.1345
# batch no.53 loss: 0.3036 time: 2183.13 accu=20 iou=0.1063
# batch no.54 loss: 0.5281 time: 2188.61 accu=19 iou=0.0931
# step loss:  0.42  accu= 0.9700  iou=0.1000
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.55 loss: 0.6336 time: 2194.69 accu=18 iou=0.0681
# batch no.56 loss: 0.3217 time: 2200.11 accu=20 iou=0.1568
# batch no.57 loss: 0.7297 time: 2205.47 accu=16 iou=0.2057
# batch no.58 loss: 0.6138 time: 2210.94 accu=19 iou=0.0632
# batch no.59 loss: 0.4298 time: 2216.27 accu=20 iou=0.0454
# step loss:  0.55  accu= 0.9300  iou=0.1078
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.60 loss: 0.5472 time: 2222.41 accu=20 iou=0.0608
# batch no.61 loss: 0.5456 time: 2227.81 accu=20 iou=0.1188
# batch no.62 loss: 0.4547 time: 2233.25 accu=20 iou=0.0728
# batch no.63 loss: 0.4539 time: 2238.61 accu=19 iou=0.1105
# batch no.64 loss: 0.4753 time: 2244.09 accu=20 iou=0.0240
# step loss:  0.50  accu= 0.9900  iou=0.0774
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.65 loss: 0.4009 time: 2250.38 accu=19 iou=0.0924
# batch no.66 loss: 0.3434 time: 2255.73 accu=20 iou=0.0833
# batch no.67 loss: 0.5369 time: 2261.14 accu=19 iou=0.0712
# batch no.68 loss: 0.3148 time: 2266.53 accu=20 iou=0.1940
# batch no.69 loss: 0.4169 time: 2272.01 accu=20 iou=0.0895
# step loss:  0.40  accu= 0.9800  iou=0.1061
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.70 loss: 0.5103 time: 2278.23 accu=20 iou=0.1177
# batch no.71 loss: 0.4485 time: 2283.64 accu=20 iou=0.0807
# batch no.72 loss: 0.5185 time: 2289.03 accu=18 iou=0.0541
# batch no.73 loss: 0.6126 time: 2294.37 accu=18 iou=0.0707
# batch no.74 loss: 0.4530 time: 2299.83 accu=19 iou=0.0839
# step loss:  0.51  accu= 0.9500  iou=0.0814
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.75 loss: 0.4958 time: 2306.06 accu=19 iou=0.0701
# batch no.76 loss: 0.5957 time: 2311.50 accu=20 iou=0.0835
# batch no.77 loss: 0.6123 time: 2316.82 accu=19 iou=0.0685
# batch no.78 loss: 0.4840 time: 2322.28 accu=19 iou=0.1672
# batch no.79 loss: 0.5121 time: 2327.64 accu=20 iou=0.1517
# step loss:  0.54  accu= 0.9700  iou=0.1082
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.80 loss: 0.6336 time: 2333.78 accu=18 iou=0.1258
# batch no.81 loss: 0.4777 time: 2339.23 accu=20 iou=0.1479
# batch no.82 loss: 0.3064 time: 2344.60 accu=20 iou=0.2328
# batch no.83 loss: 0.5149 time: 2350.01 accu=19 iou=0.0773
# batch no.84 loss: 0.4431 time: 2355.34 accu=18 iou=0.1437
# step loss:  0.48  accu= 0.9500  iou=0.1455
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.85 loss: 0.5166 time: 2361.56 accu=20 iou=0.1433
# batch no.86 loss: 0.5514 time: 2366.96 accu=20 iou=0.0913
# batch no.87 loss: 0.5598 time: 2372.44 accu=19 iou=0.0720
# batch no.88 loss: 0.5588 time: 2377.79 accu=19 iou=0.0803
# batch no.89 loss: 0.4848 time: 2383.23 accu=20 iou=0.1123
# step loss:  0.53  accu= 0.9800  iou=0.0998
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.90 loss: 0.5150 time: 2389.51 accu=20 iou=0.1254
# batch no.91 loss: 0.4642 time: 2394.82 accu=19 iou=0.1331
# batch no.92 loss: 0.6336 time: 2400.26 accu=18 iou=0.0349
# batch no.93 loss: 0.7008 time: 2405.58 accu=18 iou=0.0931
# batch no.94 loss: 0.7969 time: 2411.05 accu=17 iou=0.1175
# step loss:  0.62  accu= 0.9200  iou=0.1008
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.95 loss: 0.5808 time: 2417.36 accu=18 iou=0.0648
# batch no.96 loss: 0.7753 time: 2422.61 accu=18 iou=0.0460
# batch no.97 loss: 0.3315 time: 2428.05 accu=20 iou=0.1073
# batch no.98 loss: 0.4389 time: 2433.58 accu=19 iou=0.1720
# batch no.99 loss: 0.8215 time: 2438.92 accu=16 iou=0.1120
# step loss:  0.59  accu= 0.9100  iou=0.1004
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.100 loss: 0.4355 time: 2445.08 accu=20 iou=0.1334
# batch no.101 loss: 0.5388 time: 2450.49 accu=19 iou=0.1261
# batch no.102 loss: 0.5862 time: 2455.81 accu=18 iou=0.0830
# batch no.103 loss: 0.3926 time: 2461.22 accu=20 iou=0.1379
# batch no.104 loss: 0.3286 time: 2466.61 accu=20 iou=0.0973
# step loss:  0.46  accu= 0.9700  iou=0.1155
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.105 loss: 0.8121 time: 2472.81 accu=17 iou=0.0434
# batch no.106 loss: 0.6903 time: 2478.19 accu=19 iou=0.1051
# batch no.107 loss: 0.5185 time: 2483.61 accu=20 iou=0.1314
# batch no.108 loss: 0.4915 time: 2489.05 accu=19 iou=0.1209
# batch no.109 loss: 0.5855 time: 2494.47 accu=18 iou=0.0466
# step loss:  0.62  accu= 0.9300  iou=0.0895
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.110 loss: 0.4674 time: 2500.65 accu=19 iou=0.0645
# batch no.111 loss: 0.5020 time: 2506.00 accu=20 iou=0.1747
# batch no.112 loss: 0.3317 time: 2513.28 accu=20 iou=0.1852
# batch no.113 loss: 0.5460 time: 2518.64 accu=20 iou=0.1032
# batch no.114 loss: 0.5297 time: 2524.03 accu=19 iou=0.0862
# step loss:  0.48  accu= 0.9800  iou=0.1228
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.115 loss: 0.5987 time: 2530.28 accu=19 iou=0.1400
# batch no.116 loss: 0.7418 time: 2535.70 accu=19 iou=0.0712
# batch no.117 loss: 0.6716 time: 2541.07 accu=18 iou=0.0570
# batch no.118 loss: 0.3550 time: 2546.48 accu=20 iou=0.1148
# batch no.119 loss: 0.6716 time: 2552.01 accu=18 iou=0.1053
# step loss:  0.61  accu= 0.9400  iou=0.0977
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.120 loss: 0.5607 time: 2558.38 accu=17 iou=0.1025
# batch no.121 loss: 0.8265 time: 2563.79 accu=17 iou=0.0645
# batch no.122 loss: 0.5536 time: 2569.17 accu=18 iou=0.1433
# batch no.123 loss: 0.7170 time: 2574.52 accu=19 iou=0.0922
# batch no.124 loss: 0.6490 time: 2580.06 accu=18 iou=0.0597
# step loss:  0.66  accu= 0.8900  iou=0.0925
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.125 loss: 0.3366 time: 2586.26 accu=20 iou=0.0943
# batch no.126 loss: 0.3228 time: 2591.59 accu=19 iou=0.0820
# batch no.127 loss: 0.6590 time: 2596.94 accu=18 iou=0.0478
# batch no.128 loss: 0.7260 time: 2602.32 accu=19 iou=0.0150
# batch no.129 loss: 0.6599 time: 2607.76 accu=18 iou=0.1763
# step loss:  0.54  accu= 0.9400  iou=0.0831
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.130 loss: 0.9885 time: 2613.97 accu=17 iou=0.1270
# batch no.131 loss: 0.5264 time: 2619.38 accu=19 iou=0.0747
# batch no.132 loss: 0.3498 time: 2624.79 accu=20 iou=0.1193
# batch no.133 loss: 0.5509 time: 2630.22 accu=19 iou=0.1556
# batch no.134 loss: 0.4726 time: 2635.63 accu=20 iou=0.0496
# step loss:  0.58  accu= 0.9500  iou=0.1052
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.135 loss: 0.3981 time: 2641.89 accu=20 iou=0.0891
# batch no.136 loss: 0.3917 time: 2647.28 accu=20 iou=0.1010
# batch no.137 loss: 0.5981 time: 2652.58 accu=19 iou=0.1452
# batch no.138 loss: 0.8184 time: 2658.02 accu=18 iou=0.0571
# batch no.139 loss: 0.4640 time: 2663.46 accu=19 iou=0.1543
# step loss:  0.53  accu= 0.9600  iou=0.1094
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.140 loss: 0.6322 time: 2669.60 accu=18 iou=0.1382
# batch no.141 loss: 0.5948 time: 2675.00 accu=19 iou=0.0396
# batch no.142 loss: 0.7455 time: 2680.38 accu=18 iou=0.0675
# batch no.143 loss: 0.4421 time: 2685.69 accu=20 iou=0.1886
# batch no.144 loss: 0.5855 time: 2691.27 accu=18 iou=0.0981
# step loss:  0.60  accu= 0.9300  iou=0.1064
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.145 loss: 0.6933 time: 2697.41 accu=18 iou=0.0598
# batch no.146 loss: 0.5005 time: 2702.83 accu=19 iou=0.0850
# batch no.147 loss: 0.6663 time: 2708.23 accu=18 iou=0.1233
# batch no.148 loss: 0.4943 time: 2713.61 accu=19 iou=0.0473
# batch no.149 loss: 0.3707 time: 2718.97 accu=19 iou=0.1272
# step loss:  0.55  accu= 0.9300  iou=0.0885
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.150 loss: 0.5971 time: 2725.08 accu=19 iou=0.0924
# batch no.151 loss: 0.5703 time: 2730.40 accu=18 iou=0.1307
# batch no.152 loss: 0.6203 time: 2735.78 accu=19 iou=0.1121
# batch no.153 loss: 0.6846 time: 2741.17 accu=18 iou=0.1083
# batch no.154 loss: 0.5090 time: 2746.61 accu=19 iou=0.1697
# step loss:  0.60  accu= 0.9300  iou=0.1227
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.155 loss: 0.6783 time: 2752.87 accu=18 iou=0.0977
# batch no.156 loss: 0.7994 time: 2758.26 accu=18 iou=0.1083
# batch no.157 loss: 0.3234 time: 2763.65 accu=20 iou=0.0587
# batch no.158 loss: 0.4631 time: 2769.07 accu=20 iou=0.1462
# batch no.159 loss: 0.4450 time: 2774.49 accu=20 iou=0.1205
# step loss:  0.54  accu= 0.9600  iou=0.1063
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.160 loss: 0.4868 time: 2780.74 accu=19 iou=0.1261
# batch no.161 loss: 0.4567 time: 2786.17 accu=18 iou=0.1351
# batch no.162 loss: 0.5796 time: 2791.56 accu=19 iou=0.1516
# batch no.163 loss: 0.4140 time: 2796.90 accu=20 iou=0.0781
# batch no.164 loss: 0.5994 time: 2802.35 accu=17 iou=0.0812
# step loss:  0.51  accu= 0.9300  iou=0.1144
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.165 loss: 0.5662 time: 2808.46 accu=19 iou=0.1742
# batch no.166 loss: 0.3820 time: 2813.93 accu=19 iou=0.1468
# batch no.167 loss: 0.7880 time: 2819.35 accu=17 iou=0.0668
# batch no.168 loss: 0.4774 time: 2824.74 accu=19 iou=0.0715
# batch no.169 loss: 0.5179 time: 2830.19 accu=20 iou=0.0685
# step loss:  0.55  accu= 0.9400  iou=0.1056
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.170 loss: 0.4936 time: 2836.40 accu=19 iou=0.1241
# batch no.171 loss: 0.7018 time: 2841.68 accu=18 iou=0.0815
# batch no.172 loss: 0.9049 time: 2847.13 accu=17 iou=0.0604
# batch no.173 loss: 0.5863 time: 2852.61 accu=19 iou=0.1597
# batch no.174 loss: 0.4474 time: 2858.05 accu=20 iou=0.0750
# step loss:  0.63  accu= 0.9300  iou=0.1001
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.175 loss: 0.5944 time: 2864.19 accu=19 iou=0.0724
# batch no.176 loss: 0.3339 time: 2869.55 accu=20 iou=0.0439
# batch no.177 loss: 0.4880 time: 2874.88 accu=20 iou=0.0526
# batch no.178 loss: 0.6002 time: 2880.24 accu=20 iou=0.1643
# batch no.179 loss: 0.5934 time: 2885.66 accu=18 iou=0.1340
# step loss:  0.52  accu= 0.9700  iou=0.0934
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.180 loss: 0.7422 time: 2891.72 accu=16 iou=0.1167
# batch no.181 loss: 0.4421 time: 2897.02 accu=19 iou=0.0356
# batch no.182 loss: 0.3497 time: 2902.41 accu=20 iou=0.0246
# batch no.183 loss: 0.5896 time: 2907.84 accu=19 iou=0.1264
# batch no.184 loss: 0.9004 time: 2913.25 accu=15 iou=0.0644
# step loss:  0.60  accu= 0.8900  iou=0.0735
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.185 loss: 0.4398 time: 2919.52 accu=19 iou=0.0720
# batch no.186 loss: 0.5733 time: 2924.87 accu=18 iou=0.0776
# batch no.187 loss: 0.6067 time: 2930.30 accu=18 iou=0.1189
# batch no.188 loss: 0.4102 time: 2935.61 accu=18 iou=0.0784
# batch no.189 loss: 1.1362 time: 2940.98 accu=16 iou=0.0494
# step loss:  0.63  accu= 0.8900  iou=0.0793
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.190 loss: 0.5546 time: 2947.25 accu=19 iou=0.0099
# batch no.191 loss: 0.4760 time: 2952.53 accu=19 iou=0.0918
# batch no.192 loss: 0.4399 time: 2957.86 accu=19 iou=0.1546
# batch no.193 loss: 0.6718 time: 2963.22 accu=18 iou=0.0766
# batch no.194 loss: 0.3951 time: 2968.57 accu=19 iou=0.0666
# step loss:  0.51  accu= 0.9400  iou=0.0799
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.195 loss: 0.8164 time: 2974.76 accu=18 iou=0.0356
# batch no.196 loss: 0.3632 time: 2980.17 accu=20 iou=0.1686
# batch no.197 loss: 0.4418 time: 2985.54 accu=19 iou=0.0553
# batch no.198 loss: 0.7664 time: 2991.00 accu=16 iou=0.0829
# batch no.199 loss: 0.5802 time: 2996.32 accu=19 iou=0.0981
# step loss:  0.59  accu= 0.9200  iou=0.0881
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.200 loss: 0.5851 time: 3002.59 accu=19 iou=0.1156
# batch no.201 loss: 0.6954 time: 3007.85 accu=19 iou=0.0642
# batch no.202 loss: 0.7057 time: 3013.32 accu=18 iou=0.0840
# batch no.203 loss: 0.5794 time: 3018.71 accu=19 iou=0.0694
# batch no.204 loss: 0.3268 time: 3024.20 accu=20 iou=0.0796
# step loss:  0.58  accu= 0.9500  iou=0.0826
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.205 loss: 0.3995 time: 3030.35 accu=20 iou=0.1075
# batch no.206 loss: 0.5314 time: 3035.80 accu=17 iou=0.1185
# batch no.207 loss: 0.6992 time: 3041.23 accu=18 iou=0.1346
# batch no.208 loss: 0.4984 time: 3046.55 accu=19 iou=0.0566
# batch no.209 loss: 0.7222 time: 3052.08 accu=19 iou=0.0617
# step loss:  0.57  accu= 0.9300  iou=0.0958
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.210 loss: 0.4890 time: 3058.35 accu=19 iou=0.0332
# batch no.211 loss: 0.3713 time: 3063.68 accu=20 iou=0.0994
# batch no.212 loss: 0.5426 time: 3069.02 accu=19 iou=0.0196
# batch no.213 loss: 0.4384 time: 3074.43 accu=19 iou=0.1974
# batch no.214 loss: 0.6484 time: 3079.77 accu=18 iou=0.0708
# step loss:  0.50  accu= 0.9500  iou=0.0841
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.215 loss: 0.6243 time: 3086.16 accu=18 iou=0.1062
# batch no.216 loss: 0.8143 time: 3091.55 accu=17 iou=0.1153
# batch no.217 loss: 0.5462 time: 3096.89 accu=19 iou=0.0944
# batch no.218 loss: 0.4962 time: 3102.35 accu=19 iou=0.0685
# batch no.219 loss: 0.4168 time: 3107.72 accu=20 iou=0.0309
# step loss:  0.58  accu= 0.9300  iou=0.0831
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.220 loss: 0.5655 time: 3114.35 accu=20 iou=0.0259
# batch no.221 loss: 0.5480 time: 3120.00 accu=20 iou=0.0942
# batch no.222 loss: 0.5714 time: 3125.42 accu=20 iou=0.1215
# batch no.223 loss: 0.5501 time: 3130.91 accu=19 iou=0.1198
# batch no.224 loss: 0.6707 time: 3136.34 accu=17 iou=0.1389
# step loss:  0.58  accu= 0.9600  iou=0.1000
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.225 loss: 0.3027 time: 3142.55 accu=19 iou=0.0313
# batch no.226 loss: 0.5979 time: 3147.91 accu=18 iou=0.0899
# batch no.227 loss: 0.4742 time: 3153.23 accu=20 iou=0.0716
# batch no.228 loss: 0.5875 time: 3158.53 accu=20 iou=0.0461
# batch no.229 loss: 0.5640 time: 3163.94 accu=19 iou=0.0770
# step loss:  0.51  accu= 0.9600  iou=0.0632
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.230 loss: 0.3382 time: 3170.22 accu=20 iou=0.1052
# batch no.231 loss: 0.5360 time: 3175.64 accu=19 iou=0.1271
# batch no.232 loss: 0.3570 time: 3180.90 accu=20 iou=0.0624
# batch no.233 loss: 0.6780 time: 3186.31 accu=19 iou=0.0682
# batch no.234 loss: 0.3186 time: 3191.72 accu=20 iou=0.1137
# step loss:  0.45  accu= 0.9800  iou=0.0953
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.235 loss: 0.4991 time: 3197.95 accu=20 iou=0.1262
# batch no.236 loss: 0.4350 time: 3203.23 accu=19 iou=0.0734
# batch no.237 loss: 0.3950 time: 3208.57 accu=20 iou=0.0939
# batch no.238 loss: 0.4998 time: 3213.98 accu=19 iou=0.0900
# batch no.239 loss: 0.4454 time: 3219.32 accu=20 iou=0.0777
# step loss:  0.45  accu= 0.9800  iou=0.0922
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.240 loss: 0.4332 time: 3225.45 accu=20 iou=0.0975
# batch no.241 loss: 0.5850 time: 3230.99 accu=18 iou=0.0817
# batch no.242 loss: 0.7544 time: 3236.43 accu=19 iou=0.1537
# batch no.243 loss: 0.4461 time: 3241.84 accu=20 iou=0.1001
# batch no.244 loss: 0.3359 time: 3247.27 accu=19 iou=0.1366
# step loss:  0.51  accu= 0.9600  iou=0.1139
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.245 loss: 0.5991 time: 3253.45 accu=17 iou=0.0523
# batch no.246 loss: 0.4787 time: 3258.80 accu=19 iou=0.1234
# batch no.247 loss: 0.9889 time: 3264.21 accu=16 iou=0.1358
# batch no.248 loss: 0.7223 time: 3269.46 accu=19 iou=0.1604
# batch no.249 loss: 0.6013 time: 3274.83 accu=19 iou=0.1035
# step loss:  0.68  accu= 0.9000  iou=0.1151
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.250 loss: 0.3977 time: 3280.96 accu=19 iou=0.0907
# batch no.251 loss: 0.9890 time: 3286.35 accu=17 iou=0.0463
# batch no.252 loss: 0.3865 time: 3291.97 accu=19 iou=0.1185
# batch no.253 loss: 0.3281 time: 3297.35 accu=20 iou=0.1554
# batch no.254 loss: 0.4385 time: 3302.66 accu=19 iou=0.1059
# step loss:  0.51  accu= 0.9400  iou=0.1034
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.255 loss: 0.5330 time: 3308.91 accu=19 iou=0.1030
# batch no.256 loss: 0.6843 time: 3314.24 accu=19 iou=0.1242
# batch no.257 loss: 0.6000 time: 3319.71 accu=19 iou=0.0823
# batch no.258 loss: 0.6327 time: 3325.07 accu=19 iou=0.1235
# batch no.259 loss: 0.7386 time: 3330.44 accu=18 iou=0.1029
# step loss:  0.64  accu= 0.9400  iou=0.1072
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.260 loss: 0.6812 time: 3336.64 accu=18 iou=0.0900
# batch no.261 loss: 0.6518 time: 3342.03 accu=19 iou=0.1010
# batch no.262 loss: 0.7042 time: 3347.49 accu=19 iou=0.0236
# batch no.263 loss: 0.3862 time: 3353.08 accu=19 iou=0.1667
# batch no.264 loss: 0.5281 time: 3358.41 accu=20 iou=0.0796
# step loss:  0.59  accu= 0.9500  iou=0.0922
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.265 loss: 0.4316 time: 3364.64 accu=20 iou=0.0721
# batch no.266 loss: 0.5721 time: 3370.05 accu=19 iou=0.1415
# batch no.267 loss: 0.7685 time: 3375.42 accu=18 iou=0.0408
# batch no.268 loss: 0.4785 time: 3380.89 accu=19 iou=0.1018
# batch no.269 loss: 0.4709 time: 3386.28 accu=19 iou=0.1460
# step loss:  0.54  accu= 0.9500  iou=0.1004
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.270 loss: 0.2952 time: 3392.50 accu=20 iou=0.0733
# batch no.271 loss: 0.6019 time: 3397.84 accu=19 iou=0.0830
# batch no.272 loss: 0.7715 time: 3403.28 accu=17 iou=0.1234
# batch no.273 loss: 0.3365 time: 3408.67 accu=20 iou=0.0719
# batch no.274 loss: 0.5226 time: 3414.06 accu=19 iou=0.1498
# step loss:  0.51  accu= 0.9500  iou=0.1003
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.275 loss: 0.3739 time: 3420.18 accu=20 iou=0.1238
# batch no.276 loss: 0.5899 time: 3425.48 accu=19 iou=0.0953
# batch no.277 loss: 0.5710 time: 3430.92 accu=19 iou=0.0972
# batch no.278 loss: 0.2940 time: 3436.28 accu=20 iou=0.1259
# batch no.279 loss: 0.5192 time: 3441.67 accu=19 iou=0.0600
# step loss:  0.47  accu= 0.9700  iou=0.1004
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.280 loss: 0.3208 time: 3447.81 accu=20 iou=0.0858
# batch no.281 loss: 0.4640 time: 3453.06 accu=20 iou=0.1802
# batch no.282 loss: 0.3612 time: 3458.37 accu=18 iou=0.0602
# batch no.283 loss: 0.4196 time: 3463.70 accu=18 iou=0.1543
# batch no.284 loss: 0.8837 time: 3469.10 accu=16 iou=0.1309
# step loss:  0.49  accu= 0.9200  iou=0.1223
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.285 loss: 0.4380 time: 3475.43 accu=19 iou=0.0508
# ...
# batch no.131 loss: 0.3004 time: 6190.93 accu=20 iou=0.0639
# batch no.132 loss: 0.2677 time: 6196.33 accu=20 iou=0.1208
# batch no.133 loss: 0.3976 time: 6201.74 accu=20 iou=0.1462
# batch no.134 loss: 0.3666 time: 6207.21 accu=20 iou=0.0797
# step loss:  0.38  accu= 0.9800  iou=0.1057
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.135 loss: 0.3095 time: 6213.46 accu=20 iou=0.0818
# batch no.136 loss: 0.2879 time: 6218.74 accu=20 iou=0.1906
# batch no.137 loss: 0.4235 time: 6224.13 accu=19 iou=0.1408
# batch no.138 loss: 0.5901 time: 6229.60 accu=20 iou=0.1074
# batch no.139 loss: 0.3249 time: 6235.08 accu=20 iou=0.1377
# step loss:  0.39  accu= 0.9900  iou=0.1317
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.140 loss: 0.4176 time: 6241.27 accu=20 iou=0.1143
# batch no.141 loss: 0.4690 time: 6246.59 accu=20 iou=0.0890
# batch no.142 loss: 0.5378 time: 6251.98 accu=19 iou=0.0580
# batch no.143 loss: 0.3361 time: 6257.41 accu=20 iou=0.1822
# batch no.144 loss: 0.4399 time: 6262.86 accu=18 iou=0.1606
# step loss:  0.44  accu= 0.9700  iou=0.1208
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.145 loss: 0.4640 time: 6268.95 accu=19 iou=0.0614
# batch no.146 loss: 0.3547 time: 6274.34 accu=19 iou=0.1213
# batch no.147 loss: 0.4860 time: 6279.76 accu=19 iou=0.1292
# batch no.148 loss: 0.3461 time: 6285.29 accu=20 iou=0.0505
# batch no.149 loss: 0.2603 time: 6290.65 accu=20 iou=0.1589
# step loss:  0.38  accu= 0.9700  iou=0.1043
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.150 loss: 0.4500 time: 6296.89 accu=19 iou=0.1062
# batch no.151 loss: 0.3833 time: 6302.22 accu=20 iou=0.1526
# batch no.152 loss: 0.4292 time: 6307.64 accu=20 iou=0.0661
# batch no.153 loss: 0.5353 time: 6312.93 accu=19 iou=0.1150
# batch no.154 loss: 0.4057 time: 6318.37 accu=19 iou=0.1453
# step loss:  0.44  accu= 0.9700  iou=0.1170
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.155 loss: 0.4420 time: 6324.57 accu=18 iou=0.0893
# batch no.156 loss: 0.6128 time: 6329.98 accu=18 iou=0.1275
# batch no.157 loss: 0.2292 time: 6335.38 accu=20 iou=0.0392
# batch no.158 loss: 0.3377 time: 6340.87 accu=20 iou=0.1263
# batch no.159 loss: 0.2940 time: 6346.23 accu=20 iou=0.1349
# step loss:  0.38  accu= 0.9600  iou=0.1034
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.160 loss: 0.3678 time: 6352.74 accu=19 iou=0.1137
# batch no.161 loss: 0.3433 time: 6358.18 accu=20 iou=0.0820
# batch no.162 loss: 0.3892 time: 6363.55 accu=19 iou=0.1986
# batch no.163 loss: 0.2816 time: 6368.94 accu=20 iou=0.0748
# batch no.164 loss: 0.4041 time: 6374.37 accu=19 iou=0.1240
# step loss:  0.36  accu= 0.9700  iou=0.1186
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.165 loss: 0.4049 time: 6380.60 accu=19 iou=0.2031
# batch no.166 loss: 0.2477 time: 6386.02 accu=20 iou=0.1465
# batch no.167 loss: 0.5254 time: 6391.40 accu=17 iou=0.0980
# batch no.168 loss: 0.3422 time: 6396.72 accu=19 iou=0.0774
# batch no.169 loss: 0.3508 time: 6402.13 accu=20 iou=0.1225
# step loss:  0.37  accu= 0.9500  iou=0.1295
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.170 loss: 0.3409 time: 6408.43 accu=20 iou=0.1023
# batch no.171 loss: 0.5241 time: 6413.86 accu=19 iou=0.0789
# batch no.172 loss: 0.7199 time: 6419.22 accu=18 iou=0.0639
# batch no.173 loss: 0.3986 time: 6424.64 accu=19 iou=0.1851
# batch no.174 loss: 0.3075 time: 6430.00 accu=20 iou=0.0828
# step loss:  0.46  accu= 0.9600  iou=0.1026
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.175 loss: 0.3855 time: 6436.21 accu=19 iou=0.0863
# batch no.176 loss: 0.2255 time: 6441.58 accu=20 iou=0.0381
# batch no.177 loss: 0.3324 time: 6446.92 accu=20 iou=0.0664
# batch no.178 loss: 0.4804 time: 6452.22 accu=20 iou=0.1571
# batch no.179 loss: 0.3727 time: 6457.47 accu=20 iou=0.0744
# step loss:  0.36  accu= 0.9900  iou=0.0845
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.180 loss: 0.5118 time: 6463.56 accu=19 iou=0.1112
# batch no.181 loss: 0.3425 time: 6468.95 accu=20 iou=0.0545
# batch no.182 loss: 0.2295 time: 6474.45 accu=20 iou=0.0689
# batch no.183 loss: 0.4459 time: 6479.89 accu=20 iou=0.1112
# batch no.184 loss: 0.6760 time: 6485.30 accu=18 iou=0.0652
# step loss:  0.44  accu= 0.9700  iou=0.0822
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.185 loss: 0.2949 time: 6491.44 accu=20 iou=0.0738
# batch no.186 loss: 0.3281 time: 6496.80 accu=18 iou=0.0670
# batch no.187 loss: 0.3908 time: 6502.23 accu=19 iou=0.1502
# batch no.188 loss: 0.2972 time: 6507.65 accu=19 iou=0.0685
# batch no.189 loss: 0.9640 time: 6513.08 accu=16 iou=0.0454
# step loss:  0.46  accu= 0.9200  iou=0.0810
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.190 loss: 0.3883 time: 6519.25 accu=19 iou=0.0161
# batch no.191 loss: 0.3035 time: 6524.59 accu=20 iou=0.0988
# batch no.192 loss: 0.3208 time: 6529.93 accu=20 iou=0.1696
# batch no.193 loss: 0.4893 time: 6535.54 accu=18 iou=0.0856
# batch no.194 loss: 0.2887 time: 6541.04 accu=20 iou=0.0843
# step loss:  0.36  accu= 0.9700  iou=0.0909
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.195 loss: 0.6564 time: 6547.28 accu=18 iou=0.0303
# batch no.196 loss: 0.2376 time: 6552.54 accu=20 iou=0.2107
# batch no.197 loss: 0.3186 time: 6557.98 accu=19 iou=0.0880
# batch no.198 loss: 0.5249 time: 6563.45 accu=18 iou=0.1059
# batch no.199 loss: 0.3629 time: 6568.90 accu=20 iou=0.1189
# step loss:  0.42  accu= 0.9500  iou=0.1108
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.200 loss: 0.3845 time: 6575.06 accu=19 iou=0.1322
# batch no.201 loss: 0.4940 time: 6580.49 accu=19 iou=0.1099
# batch no.202 loss: 0.5036 time: 6585.90 accu=19 iou=0.0901
# batch no.203 loss: 0.4140 time: 6591.40 accu=20 iou=0.0672
# batch no.204 loss: 0.1774 time: 6596.83 accu=20 iou=0.1013
# step loss:  0.39  accu= 0.9700  iou=0.1001
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.205 loss: 0.2768 time: 6602.93 accu=20 iou=0.1419
# batch no.206 loss: 0.4217 time: 6608.38 accu=19 iou=0.0868
# batch no.207 loss: 0.5287 time: 6613.79 accu=18 iou=0.1974
# batch no.208 loss: 0.3379 time: 6619.22 accu=20 iou=0.0617
# batch no.209 loss: 0.5430 time: 6624.61 accu=20 iou=0.0795
# step loss:  0.42  accu= 0.9700  iou=0.1135
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.210 loss: 0.3635 time: 6630.91 accu=19 iou=0.0428
# batch no.211 loss: 0.2684 time: 6636.32 accu=20 iou=0.1328
# batch no.212 loss: 0.3698 time: 6641.61 accu=20 iou=0.0096
# batch no.213 loss: 0.3080 time: 6646.93 accu=20 iou=0.1783
# batch no.214 loss: 0.4765 time: 6652.33 accu=18 iou=0.0765
# step loss:  0.36  accu= 0.9700  iou=0.0880
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.215 loss: 0.4309 time: 6658.52 accu=18 iou=0.1311
# batch no.216 loss: 0.6009 time: 6664.02 accu=18 iou=0.1037
# batch no.217 loss: 0.4312 time: 6669.42 accu=19 iou=0.1222
# batch no.218 loss: 0.3359 time: 6674.83 accu=20 iou=0.0971
# batch no.219 loss: 0.2994 time: 6680.27 accu=20 iou=0.0597
# step loss:  0.42  accu= 0.9500  iou=0.1028
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.220 loss: 0.4191 time: 6686.42 accu=20 iou=0.0516
# batch no.221 loss: 0.3895 time: 6691.83 accu=20 iou=0.0986
# batch no.222 loss: 0.4325 time: 6697.22 accu=20 iou=0.1629
# batch no.223 loss: 0.4075 time: 6702.67 accu=20 iou=0.1588
# batch no.224 loss: 0.5053 time: 6707.98 accu=18 iou=0.1337
# step loss:  0.43  accu= 0.9800  iou=0.1211
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.225 loss: 0.2118 time: 6714.34 accu=20 iou=0.0375
# batch no.226 loss: 0.3952 time: 6719.70 accu=19 iou=0.1157
# batch no.227 loss: 0.3571 time: 6724.98 accu=20 iou=0.1241
# batch no.228 loss: 0.4514 time: 6730.50 accu=20 iou=0.0372
# batch no.229 loss: 0.3999 time: 6736.86 accu=20 iou=0.0924
# step loss:  0.36  accu= 0.9900  iou=0.0814
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.230 loss: 0.2416 time: 6743.01 accu=20 iou=0.1453
# batch no.231 loss: 0.3716 time: 6748.32 accu=20 iou=0.1126
# batch no.232 loss: 0.2710 time: 6753.64 accu=20 iou=0.0806
# batch no.233 loss: 0.5386 time: 6759.01 accu=19 iou=0.0919
# batch no.234 loss: 0.1988 time: 6764.32 accu=20 iou=0.0496
# step loss:  0.32  accu= 0.9900  iou=0.0960
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.235 loss: 0.3547 time: 6770.54 accu=20 iou=0.1286
# batch no.236 loss: 0.3271 time: 6775.90 accu=20 iou=0.0934
# batch no.237 loss: 0.3116 time: 6781.31 accu=20 iou=0.1376
# batch no.238 loss: 0.3587 time: 6786.70 accu=20 iou=0.0941
# batch no.239 loss: 0.3515 time: 6792.13 accu=20 iou=0.0864
# step loss:  0.34  accu= 1.0000  iou=0.1080
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.240 loss: 0.3214 time: 6798.37 accu=20 iou=0.0909
# batch no.241 loss: 0.4472 time: 6803.74 accu=19 iou=0.0886
# batch no.242 loss: 0.6209 time: 6809.05 accu=19 iou=0.1616
# batch no.243 loss: 0.3054 time: 6814.54 accu=20 iou=0.1211
# batch no.244 loss: 0.2468 time: 6820.01 accu=20 iou=0.1422
# step loss:  0.39  accu= 0.9800  iou=0.1209
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.245 loss: 0.4132 time: 6826.35 accu=17 iou=0.0970
# batch no.246 loss: 0.3038 time: 6831.91 accu=20 iou=0.1955
# batch no.247 loss: 0.6773 time: 6837.32 accu=18 iou=0.1658
# batch no.248 loss: 0.5605 time: 6842.69 accu=19 iou=0.1626
# batch no.249 loss: 0.4310 time: 6848.15 accu=19 iou=0.0852
# step loss:  0.48  accu= 0.9300  iou=0.1412
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.250 loss: 0.2791 time: 6854.41 accu=20 iou=0.1438
# batch no.251 loss: 0.7365 time: 6859.79 accu=18 iou=0.0608
# batch no.252 loss: 0.2821 time: 6865.22 accu=19 iou=0.1672
# batch no.253 loss: 0.2452 time: 6870.71 accu=20 iou=0.1426
# batch no.254 loss: 0.3008 time: 6876.19 accu=20 iou=0.0933
# step loss:  0.37  accu= 0.9700  iou=0.1216
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.255 loss: 0.3558 time: 6882.39 accu=20 iou=0.1213
# batch no.256 loss: 0.4844 time: 6887.72 accu=19 iou=0.1012
# batch no.257 loss: 0.4091 time: 6893.17 accu=19 iou=0.0545
# batch no.258 loss: 0.4521 time: 6898.61 accu=19 iou=0.0805
# batch no.259 loss: 0.4956 time: 6904.02 accu=20 iou=0.1441
# step loss:  0.44  accu= 0.9700  iou=0.1003
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.260 loss: 0.4910 time: 6910.25 accu=18 iou=0.1056
# batch no.261 loss: 0.4016 time: 6915.59 accu=19 iou=0.1003
# batch no.262 loss: 0.4849 time: 6920.97 accu=19 iou=0.0565
# batch no.263 loss: 0.2696 time: 6926.42 accu=19 iou=0.1715
# batch no.264 loss: 0.3996 time: 6931.84 accu=20 iou=0.0987
# step loss:  0.41  accu= 0.9500  iou=0.1065
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.265 loss: 0.3418 time: 6938.09 accu=20 iou=0.0935
# batch no.266 loss: 0.3510 time: 6943.44 accu=19 iou=0.1427
# batch no.267 loss: 0.5147 time: 6948.89 accu=18 iou=0.0239
# batch no.268 loss: 0.4004 time: 6954.34 accu=19 iou=0.1196
# batch no.269 loss: 0.3315 time: 6959.68 accu=19 iou=0.1642
# step loss:  0.39  accu= 0.9500  iou=0.1088
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.270 loss: 0.2226 time: 6965.84 accu=20 iou=0.0760
# batch no.271 loss: 0.4159 time: 6971.26 accu=20 iou=0.1267
# batch no.272 loss: 0.5258 time: 6976.65 accu=18 iou=0.1310
# batch no.273 loss: 0.2624 time: 6982.09 accu=20 iou=0.0733
# batch no.274 loss: 0.3187 time: 6987.43 accu=20 iou=0.1672
# step loss:  0.35  accu= 0.9800  iou=0.1148
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.275 loss: 0.2832 time: 6993.60 accu=20 iou=0.1675
# batch no.276 loss: 0.3921 time: 6998.92 accu=19 iou=0.1230
# batch no.277 loss: 0.4179 time: 7004.29 accu=20 iou=0.1147
# batch no.278 loss: 0.2238 time: 7009.70 accu=20 iou=0.0954
# batch no.279 loss: 0.3931 time: 7015.10 accu=19 iou=0.1205
# step loss:  0.34  accu= 0.9800  iou=0.1242
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.280 loss: 0.2348 time: 7021.29 accu=20 iou=0.0819
# batch no.281 loss: 0.3765 time: 7026.63 accu=20 iou=0.1667
# batch no.282 loss: 0.2598 time: 7031.96 accu=20 iou=0.0795
# batch no.283 loss: 0.3055 time: 7037.44 accu=19 iou=0.1875
# batch no.284 loss: 0.6204 time: 7042.91 accu=18 iou=0.1346
# step loss:  0.36  accu= 0.9700  iou=0.1300
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.285 loss: 0.3407 time: 7049.08 accu=19 iou=0.0625
# batch no.286 loss: 0.2502 time: 7054.47 accu=20 iou=0.0250
# batch no.287 loss: 0.4969 time: 7059.83 accu=19 iou=0.0603
# batch no.288 loss: 0.3194 time: 7065.15 accu=20 iou=0.0828
# batch no.289 loss: 0.3723 time: 7070.63 accu=19 iou=0.1207
# step loss:  0.36  accu= 0.9700  iou=0.0703
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.290 loss: 0.5220 time: 7076.86 accu=18 iou=0.0953
# batch no.291 loss: 0.4007 time: 7082.32 accu=20 iou=0.0756
# batch no.292 loss: 0.2092 time: 7087.72 accu=20 iou=0.0834
# batch no.293 loss: 0.7793 time: 7093.17 accu=17 iou=0.0204
# batch no.294 loss: 0.2110 time: 7098.52 accu=20 iou=0.1111
# step loss:  0.42  accu= 0.9500  iou=0.0772
# torch.Size([100, 3, 360, 640]) torch.FloatTensor
# batch no.295 loss: 0.4746 time: 7104.66 accu=20 iou=0.0972
# batch no.296 loss: 0.3964 time: 7110.08 accu=18 iou=0.1287
# batch no.297 loss: 0.2632 time: 7115.36 accu=20 iou=0.0691
# batch no.298 loss: 0.3686 time: 7120.78 accu=20 iou=0.1694
# batch no.299 loss: 0.2397 time: 7126.16 accu=20 iou=0.0377
# step loss:  0.35  accu= 0.9800  iou=0.1004
# small_batch no.0 loss: 0.5192 time: 7134.63 accu=20 iou=0.0874
# small_batch no.1 loss: 0.3169 time: 7136.97 accu=20 iou=0.1314
# small_batch no.2 loss: 0.2784 time: 7139.37 accu=19 iou=0.0909
# small_batch no.3 loss: 0.5527 time: 7141.81 accu=18 iou=0.0231
# small_batch no.4 loss: 0.6116 time: 7144.16 accu=18 iou=0.0938
# small_batch no.5 loss: 0.3786 time: 7146.69 accu=20 iou=0.1580
# small_batch no.6 loss: 0.3900 time: 7149.12 accu=19 iou=0.0803
# small_batch no.7 loss: 0.4716 time: 7151.56 accu=18 iou=0.1113
# small_batch no.8 loss: 0.4807 time: 7153.94 accu=19 iou=0.0594
# small_batch no.9 loss: 0.4976 time: 7156.31 accu=20 iou=0.0994
# small_batch no.10 loss: 0.2789 time: 7158.72 accu=19 iou=0.1904
# small_batch no.11 loss: 0.3784 time: 7161.20 accu=18 iou=0.0654
# small_batch no.12 loss: 0.2708 time: 7163.64 accu=20 iou=0.0653
# small_batch no.13 loss: 0.3295 time: 7166.03 accu=20 iou=0.0997
# small_batch no.14 loss: 0.5176 time: 7168.39 accu=18 iou=0.1554
# small_batch no.15 loss: 0.2838 time: 7170.75 accu=19 iou=0.1108
# small_batch no.16 loss: 0.4718 time: 7173.12 accu=19 iou=0.0844
# small_batch no.17 loss: 0.4759 time: 7175.50 accu=18 iou=0.1562
# small_batch no.18 loss: 0.2940 time: 7177.84 accu=20 iou=0.0698
# small_batch no.19 loss: 0.4347 time: 7180.28 accu=19 iou=0.0906
# small_batch no.20 loss: 0.4742 time: 7182.72 accu=18 iou=0.0977
# small_batch no.21 loss: 0.2950 time: 7185.12 accu=20 iou=0.1398
# small_batch no.22 loss: 0.2517 time: 7187.51 accu=20 iou=0.1145
# small_batch no.23 loss: 0.2658 time: 7189.90 accu=20 iou=0.0409
# small_batch no.24 loss: 0.2961 time: 7192.28 accu=19 iou=0.1349
# small_batch no.25 loss: 0.7259 time: 7194.65 accu=17 iou=0.1076
# small_batch no.26 loss: 0.6644 time: 7197.07 accu=17 iou=0.0724
# small_batch no.27 loss: 0.4184 time: 7199.45 accu=19 iou=0.1271
# small_batch no.28 loss: 0.5564 time: 7201.81 accu=18 iou=0.1412
# small_batch no.29 loss: 0.3825 time: 7204.20 accu=19 iou=0.1245
# small_batch no.30 loss: 0.3207 time: 7206.60 accu=20 iou=0.1087
# small_batch no.31 loss: 0.4462 time: 7208.99 accu=18 iou=0.0977
# small_batch no.32 loss: 0.4338 time: 7211.34 accu=19 iou=0.1347
# small_batch no.33 loss: 0.2665 time: 7213.73 accu=20 iou=0.2234
# small_batch no.34 loss: 0.3583 time: 7216.12 accu=19 iou=0.1264
# small_batch no.35 loss: 0.2658 time: 7218.56 accu=20 iou=0.1084
# small_batch no.36 loss: 0.4643 time: 7220.99 accu=19 iou=0.0673
# small_batch no.37 loss: 0.3791 time: 7223.40 accu=20 iou=0.1814
# small_batch no.38 loss: 0.4477 time: 7225.81 accu=19 iou=0.0644
# small_batch no.39 loss: 0.3324 time: 7228.20 accu=20 iou=0.0956
# small_batch no.40 loss: 0.4350 time: 7230.59 accu=19 iou=0.1377
# small_batch no.41 loss: 0.3955 time: 7232.95 accu=20 iou=0.1621
# small_batch no.42 loss: 0.3346 time: 7235.31 accu=19 iou=0.1596
# small_batch no.43 loss: 0.3525 time: 7237.68 accu=20 iou=0.1010
# small_batch no.44 loss: 0.6253 time: 7240.13 accu=18 iou=0.0973
# small loss: 0.41  accu= 0.9533  iou= 0.1109

# %% [markdown]
# ### Training process analysis
# First, about the learning rate<br>
# *    The learning rate is updated every 500 images. This stratery is obtained by practice. The are several steps for the weights to be updated and the loss of training data drops steadily, so it is useful and effective.
# *    It is not updated every epoch, because one epoch contains 6000 images and it is quite a long time before updating the lr, which may causes the learning rate is too large to converge and the loss won't drop for a long time.<br>
# Second, about the batch size<br>
# *    The batch size was fixed to 20 images in the begining and did not cause any problem, so we keep it.<br>
# Third, about the epoch number<br>
# *    We tried different epoch_num, 2,4,8,10,20, and 2 or 4 epochs is enough in our training strategy, because the learning rate is very small after one epoch and the weights won't change much in the next epoch.
# *    Though we only train it for 2 or 4 epochs, the classification accuracy has reached more than 90%, we think it is enough.
# Last, about the recording and showing of training process.<br>
# *    We print every batch's loss and accuracy to keep an eye on the network accuracy and the effectiveness of our training strategy. The record is very useful when analysing the results and making new decisions.

# %% [markdown]
# ## The inference stage
# Here are the codes for inference the result with the test data<br>
# * Load in the network trained before
# * Configure the inference process
# * Start testing
# * Get evaluation result
# * Inference Analysis

# %% [markdown]
# ### Load in the network we trained before
# For illustration, we load in as CPU mode and run the code here

# %%
net = mynet.yololike_v2()
mydir=os.getcwd()
net.load_state_dict(torch.load(mydir+"\yololike_v2_6000_epoch_3.pt",map_location='cpu'))

# %% [markdown]
# ### Configure the inference process
# We load in the test data in steps, and inference with batch

# %%
test_num=2500
step_num=100
bs=20
mydir=os.getcwd()
test_data_dir=mydir+"\\test_data"
test_label_dir=mydir+"\\test_label"
print(test_data_dir,test_label_dir)
# Out:
# C:\Users\Shaun\CE7454_2018\codes\DeepLearning\test_data C:\Users\Shaun\CE7454_2018\codes\DeepLearning\test_label

# %% [markdown]
# ### Start testing
# We count the testing time from reading in the data and only record the result without getting the accuracy<br>
# The loading data part consume comparable time as the net.forward()

# %%
# record test result
results=torch.zeros([test_num,84],dtype=torch.float)

start_time=time.time()
for step in range(int(test_num/step_num)):
    test_data = readin_v5.read_part_image(test_data_dir,step*step_num,step_num)
    for iter in range(int(step_num/bs)):        
        # create a minibatch
        indices=iter*bs
        prob=net.forward(test_data[indices: indices+bs])
        ## this is the most important part here to avoid RAM over use: only asign prob.data to results
        results[step*step_num+indices: step*step_num+indices+bs,:]=prob.data 
        del indices
        del prob
    del test_data
    print("step_time:",time.time()-start_time)
print("total time:",time.time()-start_time)
# Out:
# step_time: 12.999080181121826
# step_time: 25.518290758132935
# step_time: 38.03605246543884
# step_time: 50.5229856967926
# step_time: 62.93101620674133
# step_time: 75.43343353271484
# step_time: 87.88944888114929
# step_time: 100.58496356010437
# step_time: 113.16196274757385
# step_time: 125.80425024032593
# step_time: 138.41537642478943
# step_time: 151.10597014427185
# step_time: 163.8887221813202
# step_time: 177.64114117622375
# step_time: 190.42468166351318
# step_time: 203.17652869224548
# step_time: 215.75562381744385
# step_time: 228.46642684936523
# step_time: 241.1421046257019
# step_time: 253.72224855422974
# step_time: 266.600412607193
# step_time: 279.258362531662
# step_time: 291.85504817962646
# step_time: 304.4667844772339
# step_time: 316.96875524520874
# total time: 316.96875524520874

# %% [markdown]
# ### Get evaluation result
# Modify and reuse the code of training stage ^_^

# %%
# record the inference accuracy
origname="yololike_v2_6000"
record=open(origname+"_test.txt",mode='a')

# setup for getting the accuracy
test_loss=0.0
accu_count=0
iou_count=0.0
criterion1 =nn.CrossEntropyLoss()
criterion2 =nn.MSELoss()

start_time=time.time()
test_label= readin_v5.read_part_xml(test_label_dir,0,test_num)
for iter in range(int(test_num/bs)):
        indices=iter*bs
        minibatch_label= test_label[indices: indices+bs]
        prob=results[indices: indices+bs,:]
        
        # get the accuracy and IOU
        accu_batch=get_accu(prob,minibatch_label,bs)
        accu_count=accu_count+accu_batch
        iou_batch=get_iou(prob,minibatch_label,bs)
        iou_item=iou_batch.item()
        del iou_batch
        iou_count=iou_count+iou_item
        
        # get the loss
        loss=criterion1(prob[:,0:80], minibatch_label[:,0])+criterion2(prob[:,80:84]/10, minibatch_label[:,1:5].float()/100)
        test_loss=test_loss+loss.item()
        
        # show and record
        print("test_batch no."+str(iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                         " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))
        record.write("\ntest_batch no."+str(iter)+" loss: "+'{0:.4f}'.format(loss.item())+
                         " time: "+'{0:.2f}'.format(time.time()-start_time)+
                     " accu="+str(accu_batch)+" iou="+'{0:.4f}'.format(iou_item))

print("test loss:",'{0:.2f}'.format(test_loss/(test_num/bs))," accu=",'{0:.4f}'.format(accu_count/test_num),
          " iou=",'{0:.4f}'.format(iou_count/(test_num/bs)))
record.write("\ntest loss:"+'{0:.4f}'.format(test_loss/(test_num/bs))+" accuracy:"+'{0:.4f}'.format(accu_count/test_num)+
                 " iou="+'{0:.4f}'.format(iou_count/(test_num/bs)))
record.close()
# Out:
# test_batch no.0 loss: 0.2930 time: 1.03 accu=19 iou=0.1258
# test_batch no.1 loss: 0.5534 time: 1.03 accu=17 iou=0.0365
# test_batch no.2 loss: 0.4137 time: 1.05 accu=18 iou=0.1126
# test_batch no.3 loss: 0.3627 time: 1.06 accu=20 iou=0.1628
# test_batch no.4 loss: 0.3345 time: 1.06 accu=19 iou=0.0865
# test_batch no.5 loss: 0.3737 time: 1.08 accu=20 iou=0.1128
# test_batch no.6 loss: 0.4868 time: 1.08 accu=19 iou=0.1397
# test_batch no.7 loss: 0.2922 time: 1.09 accu=19 iou=0.1951
# test_batch no.8 loss: 0.2506 time: 1.09 accu=20 iou=0.0878
# test_batch no.9 loss: 0.3827 time: 1.11 accu=20 iou=0.1577
# test_batch no.10 loss: 0.3304 time: 1.11 accu=20 iou=0.1101
# test_batch no.11 loss: 0.3361 time: 1.12 accu=20 iou=0.1333
# test_batch no.12 loss: 0.3954 time: 1.14 accu=20 iou=0.0581
# test_batch no.13 loss: 0.2998 time: 1.14 accu=20 iou=0.0409
# test_batch no.14 loss: 0.4189 time: 1.16 accu=19 iou=0.0908
# test_batch no.15 loss: 0.2685 time: 1.16 accu=19 iou=0.1833
# test_batch no.16 loss: 0.5010 time: 1.17 accu=19 iou=0.0982
# test_batch no.17 loss: 0.2772 time: 1.17 accu=19 iou=0.1458
# test_batch no.18 loss: 0.3064 time: 1.19 accu=20 iou=0.1291
# test_batch no.19 loss: 0.3585 time: 1.19 accu=20 iou=0.0922
# test_batch no.20 loss: 0.2422 time: 1.20 accu=19 iou=0.0582
# test_batch no.21 loss: 0.8146 time: 1.20 accu=16 iou=0.1071
# test_batch no.22 loss: 0.3080 time: 1.23 accu=20 iou=0.1316
# test_batch no.23 loss: 0.2960 time: 1.23 accu=20 iou=0.1190
# test_batch no.24 loss: 0.2501 time: 1.24 accu=19 iou=0.0984
# test_batch no.25 loss: 0.4305 time: 1.24 accu=20 iou=0.0663
# test_batch no.26 loss: 0.2688 time: 1.26 accu=20 iou=0.1969
# test_batch no.27 loss: 0.3947 time: 1.26 accu=20 iou=0.0884
# test_batch no.28 loss: 0.2589 time: 1.27 accu=19 iou=0.0978
# test_batch no.29 loss: 0.4470 time: 1.27 accu=19 iou=0.1290
# test_batch no.30 loss: 0.3530 time: 1.29 accu=20 iou=0.1187
# test_batch no.31 loss: 0.5871 time: 1.31 accu=19 iou=0.1073
# test_batch no.32 loss: 0.3795 time: 1.31 accu=20 iou=0.0295
# test_batch no.33 loss: 0.5485 time: 1.32 accu=18 iou=0.1275
# test_batch no.34 loss: 0.5503 time: 1.32 accu=18 iou=0.0603
# test_batch no.35 loss: 0.2873 time: 1.34 accu=20 iou=0.1557
# test_batch no.36 loss: 0.2039 time: 1.34 accu=20 iou=0.0877
# test_batch no.37 loss: 0.3196 time: 1.35 accu=19 iou=0.1673
# test_batch no.38 loss: 0.3836 time: 1.37 accu=20 iou=0.1484
# test_batch no.39 loss: 0.3371 time: 1.37 accu=20 iou=0.0920
# test_batch no.40 loss: 0.2963 time: 1.38 accu=20 iou=0.0448
# test_batch no.41 loss: 0.2505 time: 1.38 accu=20 iou=0.0729
# test_batch no.42 loss: 0.3553 time: 1.40 accu=20 iou=0.1455
# test_batch no.43 loss: 0.5133 time: 1.42 accu=19 iou=0.0805
# test_batch no.44 loss: 0.3621 time: 1.42 accu=20 iou=0.1072
# test_batch no.45 loss: 0.4373 time: 1.43 accu=20 iou=0.0938
# test_batch no.46 loss: 0.2693 time: 1.44 accu=20 iou=0.1062
# test_batch no.47 loss: 0.2910 time: 1.44 accu=19 iou=0.1055
# test_batch no.48 loss: 0.1932 time: 1.45 accu=20 iou=0.0890
# test_batch no.49 loss: 0.2090 time: 1.47 accu=20 iou=0.1303
# test_batch no.50 loss: 0.2585 time: 1.47 accu=20 iou=0.0442
# test_batch no.51 loss: 0.2685 time: 1.49 accu=20 iou=0.0735
# test_batch no.52 loss: 0.3940 time: 1.49 accu=19 iou=0.0621
# test_batch no.53 loss: 0.2195 time: 1.50 accu=20 iou=0.0989
# test_batch no.54 loss: 0.2204 time: 1.50 accu=19 iou=0.2586
# test_batch no.55 loss: 0.5188 time: 1.52 accu=19 iou=0.0884
# test_batch no.56 loss: 0.2671 time: 1.53 accu=20 iou=0.0326
# test_batch no.57 loss: 0.5846 time: 1.53 accu=18 iou=0.0910
# test_batch no.58 loss: 0.4898 time: 1.55 accu=19 iou=0.1634
# test_batch no.59 loss: 0.2628 time: 1.55 accu=20 iou=0.1131
# test_batch no.60 loss: 0.2745 time: 1.56 accu=20 iou=0.1096
# test_batch no.61 loss: 0.2729 time: 1.56 accu=20 iou=0.0959
# test_batch no.62 loss: 0.2612 time: 1.58 accu=20 iou=0.1367
# test_batch no.63 loss: 0.4456 time: 1.59 accu=19 iou=0.0973
# test_batch no.64 loss: 0.4950 time: 1.59 accu=19 iou=0.1319
# test_batch no.65 loss: 0.4555 time: 1.61 accu=19 iou=0.1287
# test_batch no.66 loss: 0.3023 time: 1.62 accu=20 iou=0.0799
# test_batch no.67 loss: 0.3879 time: 1.63 accu=19 iou=0.1243
# test_batch no.68 loss: 0.5215 time: 1.63 accu=18 iou=0.0823
# test_batch no.69 loss: 0.3791 time: 1.65 accu=20 iou=0.0718
# test_batch no.70 loss: 0.3828 time: 1.65 accu=20 iou=0.0406
# test_batch no.71 loss: 0.2909 time: 1.66 accu=20 iou=0.1424
# test_batch no.72 loss: 0.4443 time: 1.68 accu=19 iou=0.0674
# test_batch no.73 loss: 0.2482 time: 1.68 accu=19 iou=0.1149
# test_batch no.74 loss: 0.3547 time: 1.69 accu=19 iou=0.0742
# test_batch no.75 loss: 0.2486 time: 1.69 accu=20 iou=0.0975
# test_batch no.76 loss: 0.4900 time: 1.71 accu=18 iou=0.0620
# test_batch no.77 loss: 0.2881 time: 1.71 accu=20 iou=0.0746
# test_batch no.78 loss: 0.6116 time: 1.72 accu=19 iou=0.1373
# test_batch no.79 loss: 0.3527 time: 1.72 accu=20 iou=0.0850
# test_batch no.80 loss: 0.5197 time: 1.74 accu=19 iou=0.0449
# test_batch no.81 loss: 0.3093 time: 1.76 accu=20 iou=0.1378
# test_batch no.82 loss: 0.2900 time: 1.76 accu=20 iou=0.2718
# test_batch no.83 loss: 0.4070 time: 1.77 accu=20 iou=0.0380
# test_batch no.84 loss: 0.3308 time: 1.77 accu=19 iou=0.0785
# test_batch no.85 loss: 0.2499 time: 1.79 accu=20 iou=0.1450
# test_batch no.86 loss: 0.5189 time: 1.81 accu=19 iou=0.1323
# test_batch no.87 loss: 0.4594 time: 1.81 accu=19 iou=0.0428
# test_batch no.88 loss: 0.3159 time: 1.81 accu=20 iou=0.0955
# test_batch no.89 loss: 0.3468 time: 1.83 accu=19 iou=0.1495
# test_batch no.90 loss: 0.5774 time: 1.83 accu=18 iou=0.1206
# test_batch no.91 loss: 0.2841 time: 1.85 accu=20 iou=0.1165
# test_batch no.92 loss: 0.3336 time: 1.86 accu=19 iou=0.1600
# test_batch no.93 loss: 0.3925 time: 1.86 accu=19 iou=0.1034
# test_batch no.94 loss: 0.2523 time: 1.88 accu=20 iou=0.1636
# test_batch no.95 loss: 0.4427 time: 1.88 accu=20 iou=0.1071
# test_batch no.96 loss: 0.3887 time: 1.89 accu=19 iou=0.1247
# test_batch no.97 loss: 0.2419 time: 1.91 accu=20 iou=0.0819
# test_batch no.98 loss: 0.4111 time: 1.91 accu=19 iou=0.1213
# test_batch no.99 loss: 0.5045 time: 1.92 accu=19 iou=0.1456
# test_batch no.100 loss: 0.8138 time: 1.94 accu=18 iou=0.0814
# test_batch no.101 loss: 0.3364 time: 1.94 accu=20 iou=0.0412
# test_batch no.102 loss: 0.3166 time: 1.95 accu=20 iou=0.1201
# test_batch no.103 loss: 0.5362 time: 1.95 accu=18 iou=0.0817
# test_batch no.104 loss: 0.3179 time: 1.97 accu=20 iou=0.1139
# test_batch no.105 loss: 0.2898 time: 1.99 accu=20 iou=0.1397
# test_batch no.106 loss: 0.7319 time: 2.00 accu=18 iou=0.1197
# test_batch no.107 loss: 0.5696 time: 2.00 accu=18 iou=0.1077
# test_batch no.108 loss: 0.2871 time: 2.01 accu=20 iou=0.0511
# test_batch no.109 loss: 0.3923 time: 2.01 accu=19 iou=0.1072
# test_batch no.110 loss: 0.5629 time: 2.03 accu=17 iou=0.1481
# test_batch no.111 loss: 0.3509 time: 2.03 accu=18 iou=0.1381
# test_batch no.112 loss: 0.6926 time: 2.04 accu=16 iou=0.0625
# test_batch no.113 loss: 0.3661 time: 2.06 accu=20 iou=0.1885
# test_batch no.114 loss: 0.3594 time: 2.06 accu=20 iou=0.0884
# test_batch no.115 loss: 0.3576 time: 2.07 accu=20 iou=0.1680
# test_batch no.116 loss: 0.4065 time: 2.07 accu=19 iou=0.1474
# test_batch no.117 loss: 0.5477 time: 2.09 accu=16 iou=0.1432
# test_batch no.118 loss: 0.2104 time: 2.11 accu=20 iou=0.1032
# test_batch no.119 loss: 0.2337 time: 2.11 accu=20 iou=0.1278
# test_batch no.120 loss: 0.5380 time: 2.12 accu=17 iou=0.2124
# test_batch no.121 loss: 0.5204 time: 2.14 accu=19 iou=0.1450
# test_batch no.122 loss: 0.2456 time: 2.14 accu=20 iou=0.1062
# test_batch no.123 loss: 0.5645 time: 2.15 accu=19 iou=0.1054
# test_batch no.124 loss: 0.4847 time: 2.15 accu=20 iou=0.0760
# test loss: 0.38  accu= 0.9652  iou= 0.1100

# %% [markdown]
# ### Inference process analysis
# We mainly take inference time into account and the quicker, the better<br>
# We split getting accuracy from inference, but the bottleneck here is not loading in data, for it shows in our another notebook that it only takes less than 1s to read in 100 images, but more than 12s to get the results in CPU mode.<br>
# So inference on GPU is a good way to solve it. When we test it on Nvidia Jetson TX2, it only need s to get the easults and the FPS=
